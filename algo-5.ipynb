# %%
import simpy
import random
import numpy as np

# Define constants based on the provided parameters
NUM_CLIENTS = random.randint(100, 200)
NUM_DATACENTERS = 1
NUM_HOSTS = 2

# Cloud node parameters
CLOUD_NODES = 10
CLOUD_CPU_POWER = (3000, 5000)  # MIPS
CLOUD_RAM = 8  # GB
CLOUD_STORAGE = 1  # TB
CLOUD_BANDWIDTH = 0.5  # Gb/s

# Fog node parameters
FOG_NODES = 10
FOG_CPU_POWER = (1000, 2800)  # MIPS
FOG_RAM = 2  # GB
FOG_STORAGE = 0.5  # TB
FOG_BANDWIDTH = 1  # Gb/s

# Task parameters
TASK_LENGTH = (2000, 56000)  # MI
DATA_SIZE = (400, 600)  # MB
TASK_SETS = [300, 600, 900, 1200, 1500]  # Different sets of task numbers

class Node:
    def __init__(self, env, cpu_power, ram, storage, bandwidth):
        self.env = env
        self.cpu_power = cpu_power
        self.ram = ram
        self.storage = storage
        self.bandwidth = bandwidth
        self.queue = simpy.Resource(env, capacity=1)
        self.total_execution_time = 0

    def process_task(self, task_length, data_size):
        # Processing time is based on task length and CPU power
        processing_time = task_length / self.cpu_power
        self.total_execution_time += processing_time
        yield self.env.timeout(processing_time)

    def calculate_energy_consumption(self, makespan):
        beta_j = 10**-8 * self.cpu_power**2
        alpha_j = 0.6 * beta_j
        active_energy = self.total_execution_time * beta_j
        idle_energy = (makespan - self.total_execution_time) * alpha_j
        total_energy = active_energy + idle_energy
        return total_energy

def generate_tasks(env, nodes, task_length_range, data_size_range, num_tasks, task_allocation):
    task_start_times = []
    task_end_times = []
    
    for task_id in range(num_tasks):
        task_length = random.randint(*task_length_range)
        data_size = random.randint(*data_size_range)
        node = nodes[task_allocation[task_id]]
        task_start_times.append(env.now)
        env.process(handle_task(env, node, task_length, data_size, task_end_times))
        yield env.timeout(1)  # Small delay to simulate task arrival interval
    
    yield env.timeout(0)  # Yield control to allow all tasks to be processed
    yield env.all_of([env.timeout(1) for _ in range(num_tasks)])  # Wait for all tasks to be completed
    makespan = max(task_end_times) - min(task_start_times)
    return makespan

def handle_task(env, node, task_length, data_size, task_end_times):
    with node.queue.request() as request:
        yield request
        #print(f"Task assigned to node with CPU power {node.cpu_power} at time {env.now}")
        yield env.process(node.process_task(task_length, data_size))
        task_end_times.append(env.now)

def fitness_function(env, all_nodes, num_tasks, task_allocation):
    makespan = env.process(generate_tasks(env, all_nodes, TASK_LENGTH, DATA_SIZE, num_tasks, task_allocation))
    env.run()
    makespan = makespan.value
    total_energy_consumption = sum(node.calculate_energy_consumption(makespan) for node in all_nodes)
    return makespan, total_energy_consumption

def qpso_optimize(num_particles, num_iterations, num_tasks, num_nodes):
    # Initialize particles
    particles = np.random.randint(0, num_nodes, (num_particles, num_tasks))
    pbest_positions = particles.copy()
    pbest_scores = np.full(num_particles, np.inf)
    gbest_position = None
    gbest_score = np.inf
    
    for _ in range(num_iterations):
        for i in range(num_particles):
            env = simpy.Environment()
            cloud_nodes = [
                Node(env, random.randint(*CLOUD_CPU_POWER), CLOUD_RAM, CLOUD_STORAGE, CLOUD_BANDWIDTH)
                for _ in range(CLOUD_NODES)
            ]
            fog_nodes = [
                Node(env, random.randint(*FOG_CPU_POWER), FOG_RAM, FOG_STORAGE, FOG_BANDWIDTH)
                for _ in range(FOG_NODES)
            ]
            all_nodes = cloud_nodes + fog_nodes
            
            makespan, energy_consumption = fitness_function(env, all_nodes, num_tasks, particles[i])
            score = makespan + energy_consumption
            
            if score < pbest_scores[i]:
                pbest_scores[i] = score
                pbest_positions[i] = particles[i].copy()
                
            if score < gbest_score:
                gbest_score = score
                gbest_position = particles[i].copy()
        
        mb = np.mean(pbest_positions, axis=0)
        beta = 1.0  # You can adjust this parameter based on your problem
        u = np.random.rand(num_particles, num_tasks)
        particles = mb + beta * np.abs(pbest_positions - particles) * np.log(1.0 / u)
        
    return gbest_position, gbest_score

def main():
    results = {}
    num_particles = 100
    num_iterations = 500

    for num_tasks in TASK_SETS:
        gbest_position, gbest_score = qpso_optimize(num_particles, num_iterations, num_tasks, CLOUD_NODES + FOG_NODES)
        
        env = simpy.Environment()
        cloud_nodes = [
            Node(env, random.randint(*CLOUD_CPU_POWER), CLOUD_RAM, CLOUD_STORAGE, CLOUD_BANDWIDTH)
            for _ in range(CLOUD_NODES)
        ]
        fog_nodes = [
            Node(env, random.randint(*FOG_CPU_POWER), FOG_RAM, FOG_STORAGE, FOG_BANDWIDTH)
            for _ in range(FOG_NODES)
        ]
        all_nodes = cloud_nodes + fog_nodes
        
        makespan, energy_consumption = fitness_function(env, all_nodes, num_tasks, gbest_position)
        
        results[num_tasks] = {
            "makespan": makespan,
            "energy_consumption": energy_consumption
        }

    # Output the makespan and energy consumption for each set of tasks
    for num_tasks, result in results.items():
        print(f"Makespan for {num_tasks} tasks: {result['makespan']}")
        print(f"Total energy consumption for {num_tasks} tasks: {result['energy_consumption']}")

if __name__ == "__main__":
    main()
# Out:
# Task assigned to node with CPU power 4503 at time 0
# Task assigned to node with CPU power 3562 at time 1
# Task assigned to node with CPU power 4946 at time 2
# Task assigned to node with CPU power 1467 at time 4
# Task assigned to node with CPU power 4503 at time 5
# Task assigned to node with CPU power 4503 at time 6.3704197201865425
# Task assigned to node with CPU power 3780 at time 7
# Task assigned to node with CPU power 3562 at time 8
# Task assigned to node with CPU power 1908 at time 10
# Task assigned to node with CPU power 2333 at time 11
# Task assigned to node with CPU power 1430 at time 12
# Task assigned to node with CPU power 4946 at time 12.059239789729075
# Task assigned to node with CPU power 1908 at time 13
# Task assigned to node with CPU power 2133 at time 14
# Task assigned to node with CPU power 3466 at time 15
# Task assigned to node with CPU power 3287 at time 16
# Task assigned to node with CPU power 4503 at time 17
# Task assigned to node with CPU power 4241 at time 18
# Task assigned to node with CPU power 4314 at time 19
# Task assigned to node with CPU power 3562 at time 19.65749578888265
# Task assigned to node with CPU power 3780 at time 20
# Task assigned to node with CPU power 4241 at time 21
# Task assigned to node with CPU power 3773 at time 22
# Task assigned to node with CPU power 2772 at time 23
# Task assigned to node with CPU power 1319 at time 28
# Task assigned to node with CPU power 3466 at time 30
# Task assigned to node with CPU power 1908 at time 31
# Task assigned to node with CPU power 4503 at time 32
# Task assigned to node with CPU power 3780 at time 32.48518518518519
# Task assigned to node with CPU power 4241 at time 32.76137703371846
# Task assigned to node with CPU power 4314 at time 33
# Task assigned to node with CPU power 1467 at time 34.61826857532379
# Task assigned to node with CPU power 3773 at time 35.78001590246488
# Task assigned to node with CPU power 2333 at time 37
# Task assigned to node with CPU power 4503 at time 37.46746613368865
# Task assigned to node with CPU power 4241 at time 38.29945767507663
# Task assigned to node with CPU power 2035 at time 39
# Task assigned to node with CPU power 1430 at time 39.612587412587416
# Task assigned to node with CPU power 3780 at time 39.66772486772487
# Task assigned to node with CPU power 2772 at time 41
# Task assigned to node with CPU power 1908 at time 41.677148846960165
# Task assigned to node with CPU power 4946 at time 42
# Task assigned to node with CPU power 4241 at time 45
# Task assigned to node with CPU power 2333 at time 45.03771967423918
# Task assigned to node with CPU power 3287 at time 47
# Task assigned to node with CPU power 2133 at time 48
# Task assigned to node with CPU power 3773 at time 51
# Task assigned to node with CPU power 4946 at time 51.38435099069956
# Task assigned to node with CPU power 3562 at time 53
# Task assigned to node with CPU power 4241 at time 56.46545626031596
# Task assigned to node with CPU power 4946 at time 56.6639708855641
# Task assigned to node with CPU power 2035 at time 57.42113022113022
# Task assigned to node with CPU power 2001 at time 58
# Task assigned to node with CPU power 3773 at time 60
# Task assigned to node with CPU power 1430 at time 60.0986013986014
# Task assigned to node with CPU power 2133 at time 62
# Task assigned to node with CPU power 2333 at time 62.52850407201029
# Task assigned to node with CPU power 4963 at time 63
# Task assigned to node with CPU power 4946 at time 63.832389809947436
# Task assigned to node with CPU power 1467 at time 65.31765507839127
# Task assigned to node with CPU power 4241 at time 66.9771280358406
# Task assigned to node with CPU power 3780 at time 69
# Task assigned to node with CPU power 1908 at time 69.05241090146751
# Task assigned to node with CPU power 4946 at time 69.76708451273757
# Task assigned to node with CPU power 1467 at time 72.43285616905249
# Task assigned to node with CPU power 4963 at time 73
# Task assigned to node with CPU power 4946 at time 73.29478366356652
# Task assigned to node with CPU power 1319 at time 74
# Task assigned to node with CPU power 2035 at time 74.05995085995086
# Task assigned to node with CPU power 3780 at time 75.94391534391535
# Task assigned to node with CPU power 3287 at time 76
# Task assigned to node with CPU power 1908 at time 76.52568134171908
# Task assigned to node with CPU power 4946 at time 77.07480792559645
# Task assigned to node with CPU power 4503 at time 78
# Task assigned to node with CPU power 4963 at time 80
# Task assigned to node with CPU power 4241 at time 80.15868898844612
# Task assigned to node with CPU power 4946 at time 80.8362312980186
# Task assigned to node with CPU power 2001 at time 81
# Task assigned to node with CPU power 2779 at time 83
# Task assigned to node with CPU power 2333 at time 83.02100300042864
# Task assigned to node with CPU power 2133 at time 84
# Task assigned to node with CPU power 4503 at time 84.58472129691317
# Task assigned to node with CPU power 4314 at time 85
# Task assigned to node with CPU power 3562 at time 87
# Task assigned to node with CPU power 2772 at time 88
# Task assigned to node with CPU power 4241 at time 88.20985616599859
# Task assigned to node with CPU power 3466 at time 91
# Task assigned to node with CPU power 2035 at time 92
# Task assigned to node with CPU power 4503 at time 93
# Task assigned to node with CPU power 1467 at time 93.3762781186094
# Task assigned to node with CPU power 3287 at time 96
# Task assigned to node with CPU power 4241 at time 96.38505069559066
# Task assigned to node with CPU power 3562 at time 97
# Task assigned to node with CPU power 1430 at time 98
# Task assigned to node with CPU power 2133 at time 99
# Task assigned to node with CPU power 4503 at time 99.87519431490118
# Task assigned to node with CPU power 1430 at time 102.6923076923077
# Task assigned to node with CPU power 4314 at time 104
# Task assigned to node with CPU power 2772 at time 105.2521645021645
# Task assigned to node with CPU power 4314 at time 106.13514140009272
# Task assigned to node with CPU power 2001 at time 106.44477761119441
# Task assigned to node with CPU power 4946 at time 107
# Task assigned to node with CPU power 3562 at time 108.9025828186412
# Task assigned to node with CPU power 3773 at time 109
# Task assigned to node with CPU power 1319 at time 110.86429112964368
# Task assigned to node with CPU power 3466 at time 111
# Task assigned to node with CPU power 3287 at time 113
# Task assigned to node with CPU power 1467 at time 113.56918882072256
# Task assigned to node with CPU power 2779 at time 116
# Task assigned to node with CPU power 3466 at time 116.6540680900173
# Task assigned to node with CPU power 2035 at time 116.90663390663391
# Task assigned to node with CPU power 1319 at time 118.62319939347992
# Task assigned to node with CPU power 4963 at time 119
# Task assigned to node with CPU power 2133 at time 121.24613220815752
# Task assigned to node with CPU power 3562 at time 121.31836047164514
# Task assigned to node with CPU power 4241 at time 122
# Task assigned to node with CPU power 4503 at time 123
# Task assigned to node with CPU power 3466 at time 124
# Task assigned to node with CPU power 3287 at time 125
# Task assigned to node with CPU power 2333 at time 126
# Task assigned to node with CPU power 4963 at time 127
# Task assigned to node with CPU power 4946 at time 128
# Task assigned to node with CPU power 4241 at time 132
# Task assigned to node with CPU power 3780 at time 133
# Task assigned to node with CPU power 3287 at time 136.8557955582598
# Task assigned to node with CPU power 4314 at time 137
# Task assigned to node with CPU power 2035 at time 137.3090909090909
# Task assigned to node with CPU power 4946 at time 137.3245046502224
# Task assigned to node with CPU power 1430 at time 139
# Task assigned to node with CPU power 2333 at time 139.08829832833263
# Task assigned to node with CPU power 4963 at time 140
# Task assigned to node with CPU power 2772 at time 141
# Task assigned to node with CPU power 2001 at time 142
# Task assigned to node with CPU power 4503 at time 143
# Task assigned to node with CPU power 2133 at time 146.3581809657759
# Task assigned to node with CPU power 3780 at time 146.9883597883598
# Task assigned to node with CPU power 2779 at time 148
# Task assigned to node with CPU power 1467 at time 149.5262440354465
# Task assigned to node with CPU power 4314 at time 151
# Task assigned to node with CPU power 3780 at time 151.0690476190476
# Task assigned to node with CPU power 2001 at time 153.9585207396302
# Task assigned to node with CPU power 4241 at time 154
# Task assigned to node with CPU power 4503 at time 154.1561181434599
# Task assigned to node with CPU power 1908 at time 156
# Task assigned to node with CPU power 2772 at time 156.56746031746033
# Task assigned to node with CPU power 2333 at time 157
# Task assigned to node with CPU power 4946 at time 162
# Task assigned to node with CPU power 3466 at time 163
# Task assigned to node with CPU power 2779 at time 164
# Task assigned to node with CPU power 2035 at time 166
# Task assigned to node with CPU power 4241 at time 166.74911577458147
# Task assigned to node with CPU power 3773 at time 170
# Task assigned to node with CPU power 2133 at time 170.2208157524613
# Task assigned to node with CPU power 4503 at time 173
# Task assigned to node with CPU power 3466 at time 173.84824004616272
# Task assigned to node with CPU power 1430 at time 174.43426573426575
# Task assigned to node with CPU power 2133 at time 175.5199249882794
# Task assigned to node with CPU power 4963 at time 177
# Task assigned to node with CPU power 2779 at time 178
# Task assigned to node with CPU power 4503 at time 179.6520097712636
# Task assigned to node with CPU power 1467 at time 179.8698023176551
# Task assigned to node with CPU power 2333 at time 180.36733819117018
# Task assigned to node with CPU power 3780 at time 181
# Task assigned to node with CPU power 1319 at time 182
# Task assigned to node with CPU power 1908 at time 182.53721174004193
# Task assigned to node with CPU power 2772 at time 183
# Task assigned to node with CPU power 4946 at time 184
# Task assigned to node with CPU power 2035 at time 184.4751842751843
# Task assigned to node with CPU power 4503 at time 185.58827448367757
# Task assigned to node with CPU power 3287 at time 186
# Task assigned to node with CPU power 2779 at time 188
# Task assigned to node with CPU power 3780 at time 189.76349206349207
# Task assigned to node with CPU power 4314 at time 190
# Task assigned to node with CPU power 1467 at time 190.44717109747785
# Task assigned to node with CPU power 3562 at time 191
# Task assigned to node with CPU power 2133 at time 193.04360056258787
# Task assigned to node with CPU power 2772 at time 193.60786435786434
# Task assigned to node with CPU power 4963 at time 194
# Task assigned to node with CPU power 4503 at time 195.78703086831004
# Task assigned to node with CPU power 4963 at time 197
# Task assigned to node with CPU power 3562 at time 198
# Task assigned to node with CPU power 4314 at time 200.3991655076495
# Task assigned to node with CPU power 4503 at time 201.69153897401733
# Task assigned to node with CPU power 4963 at time 202
# Task assigned to node with CPU power 1908 at time 204
# Task assigned to node with CPU power 3780 at time 205
# Task assigned to node with CPU power 1430 at time 208.11538461538464
# Task assigned to node with CPU power 2133 at time 208.82700421940925
# Task assigned to node with CPU power 3773 at time 210
# Task assigned to node with CPU power 4503 at time 210.50322007550523
# Task assigned to node with CPU power 2035 at time 211
# Task assigned to node with CPU power 3562 at time 211.56120157215048
# Task assigned to node with CPU power 2133 at time 212.74120956399435
# Task assigned to node with CPU power 4963 at time 212.82490429175903
# Task assigned to node with CPU power 4314 at time 213.26796476587853
# Task assigned to node with CPU power 1908 at time 214
# Task assigned to node with CPU power 3780 at time 216.86693121693122
# Task assigned to node with CPU power 2779 at time 217
# Task assigned to node with CPU power 4946 at time 218
# Task assigned to node with CPU power 4963 at time 218.70642756397342
# Task assigned to node with CPU power 3780 at time 219
# Task assigned to node with CPU power 1319 at time 220.4382107657316
# Task assigned to node with CPU power 4241 at time 222
# Task assigned to node with CPU power 3287 at time 223
# Task assigned to node with CPU power 4946 at time 224
# Task assigned to node with CPU power 2333 at time 225
# Task assigned to node with CPU power 1319 at time 226.97877179681578
# Task assigned to node with CPU power 1467 at time 227.9659168370825
# Task assigned to node with CPU power 2779 at time 228
# Task assigned to node with CPU power 3562 at time 229
# Task assigned to node with CPU power 2133 at time 229.55555555555554
# Task assigned to node with CPU power 4314 at time 230
# Task assigned to node with CPU power 2035 at time 231.22899262899261
# Task assigned to node with CPU power 2035 at time 232.48353808353806
# Task assigned to node with CPU power 1319 at time 232.55193328279
# Task assigned to node with CPU power 2772 at time 234
# Task assigned to node with CPU power 3287 at time 234.86735625190144
# Task assigned to node with CPU power 1430 at time 235.2741258741259
# Task assigned to node with CPU power 4946 at time 235.28851597250303
# Task assigned to node with CPU power 1467 at time 238.10838445807772
# Task assigned to node with CPU power 2035 at time 238.71203931203928
# Task assigned to node with CPU power 4241 at time 240
# Task assigned to node with CPU power 2779 at time 242
# Task assigned to node with CPU power 1319 at time 242.63457164518576
# Task assigned to node with CPU power 1908 at time 243.29507337526206
# Task assigned to node with CPU power 4946 at time 243.9967650626769
# Task assigned to node with CPU power 4314 at time 244
# Task assigned to node with CPU power 2133 at time 244.23675574308484
# Task assigned to node with CPU power 3780 at time 248
# Task assigned to node with CPU power 2333 at time 248.02100300042864
# Task assigned to node with CPU power 4503 at time 249
# Task assigned to node with CPU power 3466 at time 250
# Task assigned to node with CPU power 3287 at time 250.635533921509
# Task assigned to node with CPU power 1430 at time 250.64265734265737
# Task assigned to node with CPU power 4946 at time 251.32490901738777
# Task assigned to node with CPU power 1319 at time 252.18650492797576
# Task assigned to node with CPU power 4963 at time 254
# Task assigned to node with CPU power 3780 at time 254.77195767195767
# Task assigned to node with CPU power 2001 at time 255
# Task assigned to node with CPU power 3287 at time 255.17888652266507
# Task assigned to node with CPU power 2772 at time 256
# Task assigned to node with CPU power 1430 at time 257.43566433566434
# Task assigned to node with CPU power 2333 at time 258.6356622374625
# Task assigned to node with CPU power 4963 at time 259
# Task assigned to node with CPU power 4946 at time 259.4904973716134
# Task assigned to node with CPU power 4314 at time 260
# Task assigned to node with CPU power 2133 at time 262.8110642287857
# Task assigned to node with CPU power 4503 at time 263
# Task assigned to node with CPU power 4946 at time 263.9700768297614
# Task assigned to node with CPU power 3287 at time 264
# Task assigned to node with CPU power 2779 at time 266
# Task assigned to node with CPU power 4963 at time 268.5103767882329
# Task assigned to node with CPU power 2772 at time 269.5436507936508
# Task assigned to node with CPU power 1908 at time 271
# Task assigned to node with CPU power 2333 at time 271.8988426918131
# Task assigned to node with CPU power 3466 at time 272
# Task assigned to node with CPU power 3562 at time 273
# Task assigned to node with CPU power 1430 at time 273.213986013986
# Task assigned to node with CPU power 4946 at time 273.61261625556006
# Task assigned to node with CPU power 1467 at time 275.33469665985007
# Task assigned to node with CPU power 4963 at time 276.3733628853516
# Task assigned to node with CPU power 2035 at time 279
# Task assigned to node with CPU power 4963 at time 280.1237154946605
# Task assigned to node with CPU power 2133 at time 281.4542897327707
# Task assigned to node with CPU power 3773 at time 282
# Task assigned to node with CPU power 4946 at time 283.1259603720178
# Task assigned to node with CPU power 4314 at time 284
# Task assigned to node with CPU power 2333 at time 285.1945992284612
# Task assigned to node with CPU power 2001 at time 286
# Task assigned to node with CPU power 3562 at time 287
# Task assigned to node with CPU power 2772 at time 288.3315295815296
# Task assigned to node with CPU power 1430 at time 289.5055944055944
# Task assigned to node with CPU power 2333 at time 291.62194599228457
# Task assigned to node with CPU power 3773 at time 293
# Task assigned to node with CPU power 2133 at time 293.1439287388654
# Task assigned to node with CPU power 4314 at time 293.467779323134
# Task assigned to node with CPU power 2779 at time 294
# Task assigned to node with CPU power 1908 at time 295.501572327044
# Task assigned to node with CPU power 4314 at time 296
# Task assigned to node with CPU power 1467 at time 296.8329925017042
# Task assigned to node with CPU power 3773 at time 298.1799628942486
# Task assigned to node with CPU power 3562 at time 299.2158899494666
# Task assigned to node with CPU power 2035 at time 300.34054054054053
# Task assigned to node with CPU power 2772 at time 302.1583694083694
# Task assigned to node with CPU power 2133 at time 306.44116268166897
# Task assigned to node with CPU power 2133 at time 308.40412564463196
# Task assigned to node with CPU power 2001 at time 309.4312843578211
# Task assigned to node with CPU power 1908 at time 318.17976939203356
# Task assigned to node with CPU power 2772 at time 320.44624819624823
# Task assigned to node with CPU power 2035 at time 326.34742014742017
# Task assigned to node with CPU power 1467 at time 333.61758691206546
# Task assigned to node with CPU power 1467 at time 339.24676209952287
# Task assigned to node with CPU power 1467 at time 344.53237900477166
# Task assigned to node with CPU power 1467 at time 376.3353783231084
# Task assigned to node with CPU power 1467 at time 393.0668029993183
# Task assigned to node with CPU power 1467 at time 425.5637355146557
# Task assigned to node with CPU power 1467 at time 459.59645535105653
# Task assigned to node with CPU power 1467 at time 465.282208588957
# Task assigned to node with CPU power 1467 at time 475.94137695978185
# Task assigned to node with CPU power 1467 at time 484.9175187457396
# Task assigned to node with CPU power 3616 at time 0
# Task assigned to node with CPU power 4071 at time 1
# Task assigned to node with CPU power 4082 at time 2
# Task assigned to node with CPU power 3424 at time 3
# Task assigned to node with CPU power 2592 at time 4
# Task assigned to node with CPU power 3068 at time 5
# Task assigned to node with CPU power 2141 at time 7
# Task assigned to node with CPU power 3939 at time 8
# Task assigned to node with CPU power 1148 at time 10
# Task assigned to node with CPU power 4429 at time 13
# Task assigned to node with CPU power 4082 at time 15.285399314061735
# Task assigned to node with CPU power 2337 at time 16
# Task assigned to node with CPU power 3068 at time 17.988917861799216
# Task assigned to node with CPU power 3233 at time 18
# Task assigned to node with CPU power 3939 at time 18.155877126174154
# Task assigned to node with CPU power 2531 at time 19
# Task assigned to node with CPU power 1148 at time 20.11759581881533
# Task assigned to node with CPU power 2141 at time 21
# Task assigned to node with CPU power 2592 at time 21.03858024691358
# Task assigned to node with CPU power 1391 at time 22
# Task assigned to node with CPU power 4429 at time 24
# Task assigned to node with CPU power 3416 at time 25
# Task assigned to node with CPU power 4082 at time 25.652621264086232
# Task assigned to node with CPU power 4071 at time 26
# Task assigned to node with CPU power 3068 at time 26.69361147327249
# Task assigned to node with CPU power 3424 at time 28
# Task assigned to node with CPU power 3233 at time 28.51871326940922
# Task assigned to node with CPU power 3233 at time 29.44324157129601
# Task assigned to node with CPU power 2531 at time 30.799288818648755
# Task assigned to node with CPU power 1827 at time 33
# Task assigned to node with CPU power 4429 at time 35.87401219236848
# Task assigned to node with CPU power 2592 at time 36.913966049382715
# Task assigned to node with CPU power 4071 at time 37.698845492507985
# Task assigned to node with CPU power 3416 at time 39
# Task assigned to node with CPU power 2697 at time 40
# Task assigned to node with CPU power 3424 at time 40.8107476635514
# Task assigned to node with CPU power 1148 at time 41.14198606271777
# Task assigned to node with CPU power 2592 at time 41.42399691358025
# Task assigned to node with CPU power 3424 at time 41.467581775700936
# Task assigned to node with CPU power 2592 at time 42.264274691358025
# Task assigned to node with CPU power 3616 at time 43
# Task assigned to node with CPU power 2141 at time 44.14992993928071
# Task assigned to node with CPU power 2697 at time 44.19651464590285
# Task assigned to node with CPU power 4827 at time 46
# Task assigned to node with CPU power 4429 at time 47
# Task assigned to node with CPU power 3939 at time 50
# Task assigned to node with CPU power 2629 at time 51
# Task assigned to node with CPU power 3424 at time 52.81921728971963
# Task assigned to node with CPU power 2592 at time 54
# Task assigned to node with CPU power 1148 at time 54.749128919860624
# Task assigned to node with CPU power 4082 at time 56
# Task assigned to node with CPU power 2141 at time 56.42737038766931
# Task assigned to node with CPU power 3416 at time 57
# Task assigned to node with CPU power 2337 at time 58
# Task assigned to node with CPU power 1827 at time 59.455938697318004
# Task assigned to node with CPU power 2629 at time 60.38303537466717
# Task assigned to node with CPU power 1148 at time 60.55139372822299
# Task assigned to node with CPU power 2141 at time 61.80990191499299
# Task assigned to node with CPU power 2337 at time 64.55498502353444
# Task assigned to node with CPU power 3233 at time 65
# Task assigned to node with CPU power 4071 at time 68
# Task assigned to node with CPU power 2531 at time 69
# Task assigned to node with CPU power 4082 at time 69.2547770700637
# Task assigned to node with CPU power 3939 at time 70
# Task assigned to node with CPU power 3616 at time 71
# Task assigned to node with CPU power 1391 at time 72
# Task assigned to node with CPU power 2592 at time 72.77816358024691
# Task assigned to node with CPU power 1827 at time 78.63382594417077
# Task assigned to node with CPU power 4071 at time 79.28788995332842
# Task assigned to node with CPU power 4429 at time 81
# Task assigned to node with CPU power 2141 at time 81.94908921064922
# Task assigned to node with CPU power 4082 at time 82.18520333170015
# Task assigned to node with CPU power 2337 at time 82.3196405648267
# Task assigned to node with CPU power 3939 at time 83
# Task assigned to node with CPU power 2697 at time 84
# Task assigned to node with CPU power 3616 at time 85
# Task assigned to node with CPU power 4827 at time 86
# Task assigned to node with CPU power 2629 at time 89
# Task assigned to node with CPU power 4082 at time 89.69745222929937
# Task assigned to node with CPU power 3233 at time 90
# Task assigned to node with CPU power 3416 at time 91
# Task assigned to node with CPU power 1827 at time 92.19868637110017
# Task assigned to node with CPU power 2141 at time 93.40728631480616
# Task assigned to node with CPU power 2592 at time 93.8792438271605
# Task assigned to node with CPU power 4827 at time 95
# Task assigned to node with CPU power 1148 at time 95.13675958188153
# Task assigned to node with CPU power 4429 at time 96
# Task assigned to node with CPU power 4082 at time 96.52204801567859
# Task assigned to node with CPU power 2592 at time 98.12885802469135
# Task assigned to node with CPU power 4827 at time 100.24072923140668
# Task assigned to node with CPU power 2531 at time 101
# Task assigned to node with CPU power 2697 at time 102
# Task assigned to node with CPU power 3233 at time 103.64676770801114
# Task assigned to node with CPU power 3939 at time 105
# Task assigned to node with CPU power 4827 at time 105.90014501760929
# Task assigned to node with CPU power 1272 at time 106
# Task assigned to node with CPU power 2141 at time 106.72536198038298
# Task assigned to node with CPU power 2629 at time 108.39368581209585
# Task assigned to node with CPU power 1391 at time 108.75197699496765
# Task assigned to node with CPU power 4827 at time 109
# Task assigned to node with CPU power 1827 at time 109.93541324575807
# Task assigned to node with CPU power 3616 at time 110
# Task assigned to node with CPU power 4429 at time 111
# Task assigned to node with CPU power 2629 at time 111.35564853556485
# Task assigned to node with CPU power 3939 at time 113.73571972581874
# Task assigned to node with CPU power 2337 at time 114
# Task assigned to node with CPU power 2697 at time 114.24768261030775
# Task assigned to node with CPU power 1148 at time 115.66289198606272
# Task assigned to node with CPU power 3939 at time 116
# Task assigned to node with CPU power 3424 at time 118
# Task assigned to node with CPU power 3233 at time 118.48468914321064
# Task assigned to node with CPU power 3233 at time 119.77111042375503
# Task assigned to node with CPU power 3416 at time 120
# Task assigned to node with CPU power 4082 at time 122
# Task assigned to node with CPU power 3939 at time 123
# Task assigned to node with CPU power 2629 at time 124
# Task assigned to node with CPU power 3233 at time 128
# Task assigned to node with CPU power 2592 at time 131
# Task assigned to node with CPU power 2141 at time 131.36151331153664
# Task assigned to node with CPU power 3424 at time 132.46115654205607
# Task assigned to node with CPU power 4827 at time 133
# Task assigned to node with CPU power 2697 at time 134
# Task assigned to node with CPU power 3416 at time 134.04156908665107
# Task assigned to node with CPU power 3233 at time 134.7834828332818
# Task assigned to node with CPU power 2629 at time 134.88550779764168
# Task assigned to node with CPU power 3616 at time 135
# Task assigned to node with CPU power 4429 at time 136
# Task assigned to node with CPU power 3424 at time 137.16822429906543
# Task assigned to node with CPU power 2592 at time 138
# Task assigned to node with CPU power 3939 at time 139
# Task assigned to node with CPU power 2141 at time 141.89117234936944
# Task assigned to node with CPU power 2141 at time 143.63848668846333
# Task assigned to node with CPU power 4827 at time 145
# Task assigned to node with CPU power 1272 at time 145.42059748427673
# Task assigned to node with CPU power 2629 at time 146
# Task assigned to node with CPU power 1391 at time 148.30913012221424
# Task assigned to node with CPU power 1272 at time 148.36163522012578
# Task assigned to node with CPU power 1827 at time 150
# Task assigned to node with CPU power 2629 at time 151
# Task assigned to node with CPU power 3233 at time 151.6807918342097
# Task assigned to node with CPU power 3939 at time 152.87001777100787
# Task assigned to node with CPU power 2141 at time 153
# Task assigned to node with CPU power 1148 at time 154.71689895470382
# Task assigned to node with CPU power 4429 at time 155
# Task assigned to node with CPU power 2629 at time 155.62685431723088
# Task assigned to node with CPU power 3416 at time 156
# Task assigned to node with CPU power 2592 at time 157.26890432098764
# Task assigned to node with CPU power 2629 at time 159.4872575123621
# Task assigned to node with CPU power 2531 at time 160
# Task assigned to node with CPU power 3068 at time 161
# Task assigned to node with CPU power 2337 at time 162
# Task assigned to node with CPU power 3416 at time 162.9771662763466
# Task assigned to node with CPU power 4429 at time 163
# Task assigned to node with CPU power 1391 at time 163.77426312005753
# Task assigned to node with CPU power 2141 at time 165
# Task assigned to node with CPU power 4071 at time 166
# Task assigned to node with CPU power 3616 at time 167
# Task assigned to node with CPU power 2337 at time 168
# Task assigned to node with CPU power 3939 at time 169
# Task assigned to node with CPU power 4429 at time 170
# Task assigned to node with CPU power 3416 at time 171
# Task assigned to node with CPU power 3939 at time 173
# Task assigned to node with CPU power 2592 at time 173.1369598765432
# Task assigned to node with CPU power 4082 at time 176
# Task assigned to node with CPU power 1148 at time 176.0479094076655
# Task assigned to node with CPU power 3424 at time 178
# Task assigned to node with CPU power 2592 at time 178.30555555555554
# Task assigned to node with CPU power 4071 at time 179
# Task assigned to node with CPU power 1272 at time 181
# Task assigned to node with CPU power 4071 at time 181.3502824858757
# Task assigned to node with CPU power 3616 at time 181.72428097345133
# Task assigned to node with CPU power 3233 at time 183
# Task assigned to node with CPU power 3939 at time 184.73470423965475
# Task assigned to node with CPU power 3616 at time 186.3990597345133
# Task assigned to node with CPU power 3068 at time 187
# Task assigned to node with CPU power 3416 at time 188
# Task assigned to node with CPU power 2141 at time 189
# Task assigned to node with CPU power 2531 at time 191
# Task assigned to node with CPU power 4082 at time 192
# Task assigned to node with CPU power 2592 at time 192.49344135802468
# Task assigned to node with CPU power 1148 at time 192.81184668989545
# Task assigned to node with CPU power 3233 at time 194.23878750386638
# Task assigned to node with CPU power 3424 at time 195
# Task assigned to node with CPU power 1391 at time 195.2300503235083
# Task assigned to node with CPU power 3416 at time 196.31879391100702
# Task assigned to node with CPU power 1391 at time 202.51545650611075
# Task assigned to node with CPU power 3233 at time 204
# Task assigned to node with CPU power 1272 at time 204.45911949685535
# Task assigned to node with CPU power 4082 at time 205
# Task assigned to node with CPU power 2141 at time 205.2788416627744
# Task assigned to node with CPU power 3939 at time 207
# Task assigned to node with CPU power 3416 at time 207.48155737704917
# Task assigned to node with CPU power 4082 at time 208.41058304752573
# Task assigned to node with CPU power 2531 at time 208.930857368629
# Task assigned to node with CPU power 3068 at time 209
# Task assigned to node with CPU power 3416 at time 209.58372365339577
# Task assigned to node with CPU power 2337 at time 210
# Task assigned to node with CPU power 4827 at time 211
# Task assigned to node with CPU power 2592 at time 211.55131172839506
# Task assigned to node with CPU power 2592 at time 215
# Task assigned to node with CPU power 3939 at time 216
# Task assigned to node with CPU power 2697 at time 223
# Task assigned to node with CPU power 3416 at time 223.7822014051522
# Task assigned to node with CPU power 3068 at time 224
# Task assigned to node with CPU power 2337 at time 224.4163457424048
# Task assigned to node with CPU power 2592 at time 225.1658950617284
# Task assigned to node with CPU power 3939 at time 225.988068037573
# Task assigned to node with CPU power 2531 at time 226.61991307783484
# Task assigned to node with CPU power 2337 at time 226.87120239623448
# Task assigned to node with CPU power 2629 at time 227
# Task assigned to node with CPU power 3424 at time 228
# Task assigned to node with CPU power 2141 at time 228.3717888836992
# Task assigned to node with CPU power 2531 at time 228.72619517977083
# Task assigned to node with CPU power 1148 at time 231.72735191637628
# Task assigned to node with CPU power 3939 at time 232
# Task assigned to node with CPU power 2337 at time 233.8502353444587
# Task assigned to node with CPU power 1391 at time 234.7282530553559
# Task assigned to node with CPU power 4827 at time 235
# Task assigned to node with CPU power 3068 at time 235.2568448500652
# Task assigned to node with CPU power 1827 at time 236
# Task assigned to node with CPU power 3939 at time 237
# Task assigned to node with CPU power 2697 at time 239.49499443826474
# Task assigned to node with CPU power 3424 at time 240
# Task assigned to node with CPU power 3233 at time 241
# Task assigned to node with CPU power 3416 at time 242
# Task assigned to node with CPU power 2592 at time 243.55208333333334
# Task assigned to node with CPU power 3939 at time 245
# Task assigned to node with CPU power 1272 at time 245.82861635220127
# Task assigned to node with CPU power 3424 at time 249.47167056074767
# Task assigned to node with CPU power 1272 at time 252
# Task assigned to node with CPU power 2141 at time 252.42129845866415
# Task assigned to node with CPU power 3416 at time 252.70462529274005
# Task assigned to node with CPU power 2592 at time 253.6604938271605
# Task assigned to node with CPU power 2337 at time 253.8806161745828
# Task assigned to node with CPU power 1827 at time 255
# Task assigned to node with CPU power 2697 at time 256.9239896180942
# Task assigned to node with CPU power 4429 at time 257
# Task assigned to node with CPU power 1391 at time 258.21063982746233
# Task assigned to node with CPU power 2592 at time 259.65740740740745
# Task assigned to node with CPU power 3233 at time 260
# Task assigned to node with CPU power 4082 at time 263
# Task assigned to node with CPU power 3616 at time 265
# Task assigned to node with CPU power 2592 at time 265.9791666666667
# Task assigned to node with CPU power 3939 at time 267
# Task assigned to node with CPU power 2629 at time 268
# Task assigned to node with CPU power 4827 at time 269
# Task assigned to node with CPU power 1827 at time 271.67432950191574
# Task assigned to node with CPU power 2531 at time 272
# Task assigned to node with CPU power 4082 at time 272.4652131308182
# Task assigned to node with CPU power 1391 at time 275.27318475916616
# Task assigned to node with CPU power 2697 at time 275.48943270300333
# Task assigned to node with CPU power 2531 at time 276
# Task assigned to node with CPU power 2141 at time 276.8542737038767
# Task assigned to node with CPU power 3424 at time 277
# Task assigned to node with CPU power 1148 at time 277.3414634146341
# Task assigned to node with CPU power 2141 at time 281.9747781410556
# Task assigned to node with CPU power 2629 at time 282
# Task assigned to node with CPU power 1272 at time 282.76650943396226
# Task assigned to node with CPU power 4082 at time 283.0632043116119
# Task assigned to node with CPU power 1827 at time 283.82758620689657
# Task assigned to node with CPU power 4071 at time 285
# Task assigned to node with CPU power 3233 at time 286
# Task assigned to node with CPU power 3424 at time 287
# Task assigned to node with CPU power 4429 at time 288
# Task assigned to node with CPU power 3068 at time 289
# Task assigned to node with CPU power 1391 at time 291.74550682961905
# Task assigned to node with CPU power 2531 at time 293
# Task assigned to node with CPU power 2629 at time 294
# Task assigned to node with CPU power 2697 at time 295
# Task assigned to node with CPU power 4082 at time 295.2672709456148
# Task assigned to node with CPU power 3939 at time 296
# Task assigned to node with CPU power 1148 at time 297.98257839721254
# Task assigned to node with CPU power 4071 at time 298.3384917710636
# Task assigned to node with CPU power 4082 at time 299.1925526702596
# Task assigned to node with CPU power 1272 at time 301.9882075471698
# Task assigned to node with CPU power 2141 at time 304.68425969173285
# Task assigned to node with CPU power 4071 at time 307.0201424711373
# Task assigned to node with CPU power 2141 at time 310.0023353573097
# Task assigned to node with CPU power 4071 at time 310.33480717268486
# Task assigned to node with CPU power 2141 at time 314.22652965903785
# Task assigned to node with CPU power 1272 at time 315.08805031446536
# Task assigned to node with CPU power 1272 at time 317.6132075471698
# Task assigned to node with CPU power 1391 at time 318.1502516175414
# Task assigned to node with CPU power 2141 at time 323.89537599252685
# Task assigned to node with CPU power 1148 at time 337.1567944250871
# Task assigned to node with CPU power 2141 at time 349.22652965903785
# Task assigned to node with CPU power 2141 at time 353.05184493227466
# Task assigned to node with CPU power 1391 at time 355.20632638389657
# Task assigned to node with CPU power 1391 at time 381.9151689432064
# Task assigned to node with CPU power 1391 at time 384.20488856937465
# Task assigned to node with CPU power 1148 at time 385.7987804878049
# Task assigned to node with CPU power 1148 at time 391.7404181184669
# Task assigned to node with CPU power 1391 at time 392.52767792954717
# Task assigned to node with CPU power 1391 at time 415.4011502516176
# Task assigned to node with CPU power 1148 at time 421.3074912891986
# Task assigned to node with CPU power 1391 at time 438.8030194104961
# Task assigned to node with CPU power 1148 at time 453.11933797909404
# Task assigned to node with CPU power 1148 at time 468.30487804878044
# Task assigned to node with CPU power 1148 at time 478.5662020905923
# Task assigned to node with CPU power 1148 at time 497.8641114982578
# Task assigned to node with CPU power 2782 at time 0
# Task assigned to node with CPU power 2058 at time 1
# Task assigned to node with CPU power 1428 at time 2
# Task assigned to node with CPU power 1074 at time 3
# Task assigned to node with CPU power 4690 at time 4
# Task assigned to node with CPU power 3126 at time 5
# Task assigned to node with CPU power 4595 at time 6
# Task assigned to node with CPU power 1489 at time 7
# Task assigned to node with CPU power 4416 at time 9
# Task assigned to node with CPU power 4262 at time 10
# Task assigned to node with CPU power 1428 at time 12
# Task assigned to node with CPU power 3684 at time 13
# Task assigned to node with CPU power 4690 at time 13.427078891257995
# Task assigned to node with CPU power 2058 at time 15
# Task assigned to node with CPU power 3126 at time 15.882917466410749
# Task assigned to node with CPU power 2782 at time 16
# Task assigned to node with CPU power 1942 at time 20
# Task assigned to node with CPU power 1489 at time 20.788448623237073
# Task assigned to node with CPU power 3126 at time 21.215930902111324
# Task assigned to node with CPU power 4262 at time 22
# Task assigned to node with CPU power 3126 at time 23.147472808701217
# Task assigned to node with CPU power 2058 at time 24.32167152575316
# Task assigned to node with CPU power 1301 at time 25
# Task assigned to node with CPU power 4262 at time 26
# Task assigned to node with CPU power 2405 at time 27
# Task assigned to node with CPU power 4690 at time 28
# Task assigned to node with CPU power 1942 at time 31
# Task assigned to node with CPU power 4690 at time 32.30106609808102
# Task assigned to node with CPU power 3725 at time 33
# Task assigned to node with CPU power 4262 at time 33.09831065227593
# Task assigned to node with CPU power 3684 at time 34
# Task assigned to node with CPU power 1489 at time 34.96776359973136
# Task assigned to node with CPU power 2782 at time 35.55355859094177
# Task assigned to node with CPU power 4595 at time 36
# Task assigned to node with CPU power 4416 at time 38
# Task assigned to node with CPU power 3725 at time 39.83114093959732
# Task assigned to node with CPU power 3523 at time 40
# Task assigned to node with CPU power 1301 at time 41
# Task assigned to node with CPU power 4325 at time 42
# Task assigned to node with CPU power 2058 at time 42.91010689990282
# Task assigned to node with CPU power 1428 at time 45
# Task assigned to node with CPU power 3193 at time 47
# Task assigned to node with CPU power 2782 at time 47.636232925952555
# Task assigned to node with CPU power 2456 at time 48
# Task assigned to node with CPU power 4595 at time 50
# Task assigned to node with CPU power 3684 at time 51
# Task assigned to node with CPU power 1074 at time 51.201117318435756
# Task assigned to node with CPU power 3725 at time 52.841610738255035
# Task assigned to node with CPU power 4690 at time 53
# Task assigned to node with CPU power 2782 at time 54
# Task assigned to node with CPU power 4325 at time 56
# Task assigned to node with CPU power 3193 at time 57
# Task assigned to node with CPU power 4690 at time 59.71577825159915
# Task assigned to node with CPU power 3725 at time 59.916241610738254
# Task assigned to node with CPU power 4325 at time 60
# Task assigned to node with CPU power 3523 at time 61
# Task assigned to node with CPU power 3126 at time 62
# Task assigned to node with CPU power 2405 at time 63
# Task assigned to node with CPU power 1489 at time 64
# Task assigned to node with CPU power 4262 at time 66
# Task assigned to node with CPU power 2456 at time 67
# Task assigned to node with CPU power 4325 at time 68.94635838150289
# Task assigned to node with CPU power 3725 at time 69.33771812080536
# Task assigned to node with CPU power 2058 at time 69.81681243926143
# Task assigned to node with CPU power 4325 at time 70.51745664739884
# Task assigned to node with CPU power 3725 at time 70.60402684563758
# Task assigned to node with CPU power 3523 at time 72
# Task assigned to node with CPU power 4595 at time 73
# Task assigned to node with CPU power 2782 at time 73.42451473759886
# Task assigned to node with CPU power 1489 at time 76
# Task assigned to node with CPU power 1301 at time 76.22059953881629
# Task assigned to node with CPU power 1942 at time 78
# Task assigned to node with CPU power 2782 at time 79.17972681524084
# Task assigned to node with CPU power 1428 at time 79.96708683473389
# Task assigned to node with CPU power 3126 at time 80
# Task assigned to node with CPU power 4325 at time 80.38335260115608
# Task assigned to node with CPU power 4595 at time 81
# Task assigned to node with CPU power 2456 at time 81.89495114006515
# Task assigned to node with CPU power 3725 at time 82
# Task assigned to node with CPU power 3523 at time 82.37893840476866
# Task assigned to node with CPU power 1301 at time 83.43889315910837
# Task assigned to node with CPU power 1222 at time 84
# Task assigned to node with CPU power 4262 at time 86
# Task assigned to node with CPU power 3523 at time 87
# Task assigned to node with CPU power 3193 at time 89
# Task assigned to node with CPU power 2456 at time 89.79315960912052
# Task assigned to node with CPU power 3523 at time 91
# Task assigned to node with CPU power 4595 at time 91.43939064200218
# Task assigned to node with CPU power 2058 at time 91.9013605442177
# Task assigned to node with CPU power 1301 at time 92
# Task assigned to node with CPU power 2782 at time 92.68511861969807
# Task assigned to node with CPU power 1489 at time 93
# Task assigned to node with CPU power 4325 at time 93.25757225433527
# Task assigned to node with CPU power 3684 at time 95
# Task assigned to node with CPU power 2405 at time 96
# Task assigned to node with CPU power 4325 at time 97.23398843930637
# Task assigned to node with CPU power 3126 at time 101
# Task assigned to node with CPU power 4595 at time 102.18215451577802
# Task assigned to node with CPU power 4325 at time 107.12369942196533
# Task assigned to node with CPU power 4262 at time 108
# Task assigned to node with CPU power 3684 at time 108.36237785016287
# Task assigned to node with CPU power 1428 at time 108.7296918767507
# Task assigned to node with CPU power 1222 at time 109.50654664484452
# Task assigned to node with CPU power 3684 at time 109.99674267100978
# Task assigned to node with CPU power 2456 at time 110
# Task assigned to node with CPU power 4690 at time 112
# Task assigned to node with CPU power 1074 at time 114
# Task assigned to node with CPU power 1428 at time 115.25910364145659
# Task assigned to node with CPU power 2058 at time 115.85422740524783
# Task assigned to node with CPU power 3725 at time 116
# Task assigned to node with CPU power 3126 at time 116.59692898272553
# Task assigned to node with CPU power 1489 at time 116.89993284083278
# Task assigned to node with CPU power 3684 at time 117.72937024972856
# Task assigned to node with CPU power 3193 at time 119
# Task assigned to node with CPU power 1074 at time 123
# Task assigned to node with CPU power 1301 at time 124
# Task assigned to node with CPU power 3684 at time 124.19543973941369
# Task assigned to node with CPU power 2058 at time 124.96015549076775
# Task assigned to node with CPU power 2405 at time 125
# Task assigned to node with CPU power 1301 at time 127.65795541890853
# Task assigned to node with CPU power 1489 at time 128.65681665547348
# Task assigned to node with CPU power 3725 at time 129
# Task assigned to node with CPU power 3725 at time 130.84295302013422
# Task assigned to node with CPU power 3126 at time 132
# Task assigned to node with CPU power 2456 at time 132.2540716612378
# Task assigned to node with CPU power 2058 at time 132.4310009718173
# Task assigned to node with CPU power 2405 at time 133.0162162162162
# Task assigned to node with CPU power 3684 at time 136
# Task assigned to node with CPU power 3193 at time 137
# Task assigned to node with CPU power 1489 at time 137.65144392209538
# Task assigned to node with CPU power 4262 at time 138
# Task assigned to node with CPU power 4595 at time 139
# Task assigned to node with CPU power 1222 at time 139.08674304418986
# Task assigned to node with CPU power 2456 at time 139.15960912052117
# Task assigned to node with CPU power 4325 at time 141
# Task assigned to node with CPU power 1489 at time 141.8925453324379
# Task assigned to node with CPU power 3523 at time 142
# Task assigned to node with CPU power 3126 at time 143
# Task assigned to node with CPU power 1301 at time 145.010760953113
# Task assigned to node with CPU power 1222 at time 146.3240589198036
# Task assigned to node with CPU power 4595 at time 148.46180631120782
# Task assigned to node with CPU power 4262 at time 149.34420459877992
# Task assigned to node with CPU power 3523 at time 151.43315356230485
# Task assigned to node with CPU power 4416 at time 152
# Task assigned to node with CPU power 3126 at time 152.72040946896993
# Task assigned to node with CPU power 2058 at time 153
# Task assigned to node with CPU power 1428 at time 153.95238095238096
# Task assigned to node with CPU power 1074 at time 156
# Task assigned to node with CPU power 4416 at time 157
# Task assigned to node with CPU power 4595 at time 157.78563656147986
# Task assigned to node with CPU power 2782 at time 158
# Task assigned to node with CPU power 3684 at time 159
# Task assigned to node with CPU power 3126 at time 159.56365962891874
# Task assigned to node with CPU power 4262 at time 159.60394181135618
# Task assigned to node with CPU power 4262 at time 162.24167057719382
# Task assigned to node with CPU power 1942 at time 163
# Task assigned to node with CPU power 2782 at time 164
# Task assigned to node with CPU power 3523 at time 167
# Task assigned to node with CPU power 3193 at time 169
# Task assigned to node with CPU power 1942 at time 169.4572605561277
# Task assigned to node with CPU power 4416 at time 170
# Task assigned to node with CPU power 2782 at time 172
# Task assigned to node with CPU power 4595 at time 173
# Task assigned to node with CPU power 1489 at time 173.6017461383479
# Task assigned to node with CPU power 2456 at time 176
# Task assigned to node with CPU power 2405 at time 178
# Task assigned to node with CPU power 2058 at time 179
# Task assigned to node with CPU power 1301 at time 179.5564950038432
# Task assigned to node with CPU power 3523 at time 179.86659097360206
# Task assigned to node with CPU power 4595 at time 181
# Task assigned to node with CPU power 3684 at time 182
# Task assigned to node with CPU power 1428 at time 183.82703081232495
# Task assigned to node with CPU power 4325 at time 184
# Task assigned to node with CPU power 1489 at time 184.82941571524515
# Task assigned to node with CPU power 1222 at time 186.0949263502455
# Task assigned to node with CPU power 4595 at time 187.06768226332971
# Task assigned to node with CPU power 3725 at time 188
# Task assigned to node with CPU power 1074 at time 188.9022346368715
# Task assigned to node with CPU power 2782 at time 189
# Task assigned to node with CPU power 3523 at time 189.73289809821176
# Task assigned to node with CPU power 4416 at time 193
# Task assigned to node with CPU power 1222 at time 193.18985270049097
# Task assigned to node with CPU power 4595 at time 193.3532100108814
# Task assigned to node with CPU power 2456 at time 193.89698697068405
# Task assigned to node with CPU power 1301 at time 196
# Task assigned to node with CPU power 4416 at time 197.34465579710144
# ...
# Task assigned to node with CPU power 4358 at time 107.14456172556218
# Task assigned to node with CPU power 4825 at time 110
# Task assigned to node with CPU power 3395 at time 111
# Task assigned to node with CPU power 4062 at time 111.25307730182176
# Task assigned to node with CPU power 1386 at time 111.31673881673882
# Task assigned to node with CPU power 3519 at time 116
# Task assigned to node with CPU power 1593 at time 118.16446955430007
# Task assigned to node with CPU power 3395 at time 118.18438880706923
# Task assigned to node with CPU power 2012 at time 120.79721669980118
# Task assigned to node with CPU power 4358 at time 121
# Task assigned to node with CPU power 1593 at time 121.44256120527308
# Task assigned to node with CPU power 3733 at time 122
# Task assigned to node with CPU power 1593 at time 125.33961079723792
# Task assigned to node with CPU power 1718 at time 125.83294528521537
# Task assigned to node with CPU power 4595 at time 126
# Task assigned to node with CPU power 3519 at time 126.29468599033817
# Task assigned to node with CPU power 3733 at time 127.97294401285829
# Task assigned to node with CPU power 2451 at time 128
# Task assigned to node with CPU power 4358 at time 129.46948141349242
# Task assigned to node with CPU power 4595 at time 130
# Task assigned to node with CPU power 1087 at time 132.15179392824285
# Task assigned to node with CPU power 4825 at time 134
# Task assigned to node with CPU power 3733 at time 134.35521028663274
# Task assigned to node with CPU power 2478 at time 135
# Task assigned to node with CPU power 3519 at time 135.12787723785166
# Task assigned to node with CPU power 2451 at time 137
# Task assigned to node with CPU power 1593 at time 137.97865662272443
# Task assigned to node with CPU power 4825 at time 139
# Task assigned to node with CPU power 4181 at time 140
# Task assigned to node with CPU power 3455 at time 141
# Task assigned to node with CPU power 4595 at time 141.71360174102284
# Task assigned to node with CPU power 4825 at time 142
# Task assigned to node with CPU power 4358 at time 142.13767783386874
# Task assigned to node with CPU power 1718 at time 143.33178114086147
# Task assigned to node with CPU power 3395 at time 144
# Task assigned to node with CPU power 1386 at time 144.3138528138528
# Task assigned to node with CPU power 2012 at time 145.448310139165
# Task assigned to node with CPU power 1593 at time 146.2347771500314
# Task assigned to node with CPU power 2523 at time 147
# Task assigned to node with CPU power 1718 at time 147.9778812572759
# Task assigned to node with CPU power 3519 at time 149.72009093492468
# Task assigned to node with CPU power 1386 at time 149.72366522366522
# Task assigned to node with CPU power 4358 at time 149.76663607159247
# Task assigned to node with CPU power 3455 at time 149.80578871201158
# Task assigned to node with CPU power 2451 at time 150
# Task assigned to node with CPU power 1593 at time 153.21594475831765
# Task assigned to node with CPU power 3395 at time 154
# Task assigned to node with CPU power 2523 at time 154.14665081252477
# Task assigned to node with CPU power 2537 at time 155
# Task assigned to node with CPU power 4062 at time 157
# Task assigned to node with CPU power 4358 at time 159.04749885268473
# Task assigned to node with CPU power 3519 at time 160.16510372264847
# Task assigned to node with CPU power 2012 at time 161.4418489065606
# Task assigned to node with CPU power 3395 at time 161.64094256259204
# Task assigned to node with CPU power 1593 at time 161.86189579409918
# Task assigned to node with CPU power 4825 at time 163
# Task assigned to node with CPU power 4358 at time 163.11083065626434
# Task assigned to node with CPU power 4062 at time 164.25898572131956
# Task assigned to node with CPU power 3733 at time 166
# Task assigned to node with CPU power 4181 at time 170
# Task assigned to node with CPU power 1087 at time 171.2161913523459
# Task assigned to node with CPU power 4181 at time 173
# Task assigned to node with CPU power 2523 at time 173.3202536662703
# Task assigned to node with CPU power 2182 at time 174
# Task assigned to node with CPU power 4062 at time 174.86213687838506
# Task assigned to node with CPU power 2478 at time 175
# Task assigned to node with CPU power 4358 at time 175.59981642955483
# Task assigned to node with CPU power 3733 at time 177.04553978033752
# Task assigned to node with CPU power 2523 at time 177.25961157352359
# Task assigned to node with CPU power 2537 at time 178
# Task assigned to node with CPU power 1593 at time 179.45762711864407
# Task assigned to node with CPU power 4181 at time 180.91030853862713
# Task assigned to node with CPU power 2012 at time 182.83101391650098
# Task assigned to node with CPU power 3733 at time 185
# Task assigned to node with CPU power 4826 at time 186
# Task assigned to node with CPU power 1386 at time 186.001443001443
# Task assigned to node with CPU power 4358 at time 187
# Task assigned to node with CPU power 4062 at time 187.26292466765142
# Task assigned to node with CPU power 1718 at time 188
# Task assigned to node with CPU power 4595 at time 189
# Task assigned to node with CPU power 2182 at time 190
# Task assigned to node with CPU power 2523 at time 191
# Task assigned to node with CPU power 2012 at time 191.03180914512922
# Task assigned to node with CPU power 3455 at time 192
# Task assigned to node with CPU power 1718 at time 193.22060535506404
# Task assigned to node with CPU power 2451 at time 194
# Task assigned to node with CPU power 4595 at time 197
# Task assigned to node with CPU power 4358 at time 198
# Task assigned to node with CPU power 2451 at time 199
# Task assigned to node with CPU power 2537 at time 199.51832873472605
# Task assigned to node with CPU power 4826 at time 200
# Task assigned to node with CPU power 3455 at time 202
# Task assigned to node with CPU power 1386 at time 204.87662337662337
# Task assigned to node with CPU power 2537 at time 207.61687031927474
# Task assigned to node with CPU power 1087 at time 208.26862925482982
# Task assigned to node with CPU power 2523 at time 209
# Task assigned to node with CPU power 2182 at time 210.28093492208984
# Task assigned to node with CPU power 1593 at time 211.40929064657877
# Task assigned to node with CPU power 4826 at time 212
# Task assigned to node with CPU power 2478 at time 213
# Task assigned to node with CPU power 1718 at time 213.90803259604192
# Task assigned to node with CPU power 3519 at time 214
# Task assigned to node with CPU power 4595 at time 215
# Task assigned to node with CPU power 3395 at time 216
# Task assigned to node with CPU power 3455 at time 216.02691751085382
# Task assigned to node with CPU power 2182 at time 217.04170485792852
# Task assigned to node with CPU power 1386 at time 217.92929292929293
# Task assigned to node with CPU power 2012 at time 218.3628230616302
# Task assigned to node with CPU power 4826 at time 221
# Task assigned to node with CPU power 1593 at time 221.57187696170746
# Task assigned to node with CPU power 2523 at time 225.54141894569958
# Task assigned to node with CPU power 2537 at time 226
# Task assigned to node with CPU power 1386 at time 231.0981240981241
# Task assigned to node with CPU power 4826 at time 231.91276419394944
# Task assigned to node with CPU power 3395 at time 231.9882179675994
# Task assigned to node with CPU power 3455 at time 232
# Task assigned to node with CPU power 2451 at time 233
# Task assigned to node with CPU power 4358 at time 234
# Task assigned to node with CPU power 2182 at time 234.33180568285977
# Task assigned to node with CPU power 2478 at time 235.56860371267152
# Task assigned to node with CPU power 4826 at time 237.16639038541234
# Task assigned to node with CPU power 3395 at time 237.39499263622974
# Task assigned to node with CPU power 4181 at time 238
# Task assigned to node with CPU power 2182 at time 238.07011915673695
# Task assigned to node with CPU power 4825 at time 239
# Task assigned to node with CPU power 2523 at time 240.40784780023782
# Task assigned to node with CPU power 4358 at time 241.73106929784305
# Task assigned to node with CPU power 4595 at time 243
# Task assigned to node with CPU power 2182 at time 243.56416131989002
# Task assigned to node with CPU power 2537 at time 244.45723295230587
# Task assigned to node with CPU power 2012 at time 245.01441351888667
# Task assigned to node with CPU power 4358 at time 246
# Task assigned to node with CPU power 2182 at time 246.5614115490376
# Task assigned to node with CPU power 3455 at time 247
# Task assigned to node with CPU power 1593 at time 248.67733835530444
# Task assigned to node with CPU power 2478 at time 248.78692493946733
# Task assigned to node with CPU power 4826 at time 249
# Task assigned to node with CPU power 3395 at time 250
# Task assigned to node with CPU power 4358 at time 251
# Task assigned to node with CPU power 2451 at time 251.5516115871073
# Task assigned to node with CPU power 1386 at time 251.984126984127
# Task assigned to node with CPU power 3733 at time 253
# Task assigned to node with CPU power 4595 at time 254
# Task assigned to node with CPU power 2451 at time 254.51611587107303
# Task assigned to node with CPU power 1087 at time 255.5804967801288
# Task assigned to node with CPU power 2012 at time 256.37723658051686
# Task assigned to node with CPU power 4825 at time 258
# Task assigned to node with CPU power 3519 at time 259
# Task assigned to node with CPU power 2012 at time 259.74850894632203
# Task assigned to node with CPU power 2537 at time 261.8088293259756
# Task assigned to node with CPU power 2478 at time 262
# Task assigned to node with CPU power 1087 at time 262.05151793928246
# Task assigned to node with CPU power 2537 at time 264
# Task assigned to node with CPU power 4358 at time 265
# Task assigned to node with CPU power 2451 at time 265.9885760913913
# Task assigned to node with CPU power 4826 at time 266
# Task assigned to node with CPU power 2182 at time 267.8803849679193
# Task assigned to node with CPU power 3519 at time 268
# Task assigned to node with CPU power 1386 at time 268.4155844155844
# Task assigned to node with CPU power 1593 at time 268.4783427495292
# Task assigned to node with CPU power 2523 at time 269
# Task assigned to node with CPU power 3733 at time 270
# Task assigned to node with CPU power 2451 at time 273.6972664218686
# Task assigned to node with CPU power 4826 at time 275.4341069208454
# Task assigned to node with CPU power 1386 at time 275.82034632034635
# Task assigned to node with CPU power 3519 at time 276
# Task assigned to node with CPU power 4825 at time 279
# Task assigned to node with CPU power 2451 at time 279.7927376580987
# Task assigned to node with CPU power 3519 at time 280.72833191247514
# Task assigned to node with CPU power 2012 at time 280.837972166998
# Task assigned to node with CPU power 3733 at time 281
# Task assigned to node with CPU power 3455 at time 282
# Task assigned to node with CPU power 3519 at time 282.303495311168
# Task assigned to node with CPU power 1593 at time 282.3948524795982
# Task assigned to node with CPU power 4181 at time 284
# Task assigned to node with CPU power 4826 at time 285
# Task assigned to node with CPU power 4825 at time 286
# Task assigned to node with CPU power 1386 at time 286.19985569985573
# Task assigned to node with CPU power 2182 at time 286.9537121906508
# Task assigned to node with CPU power 2478 at time 287
# Task assigned to node with CPU power 2523 at time 287.5053507728894
# Task assigned to node with CPU power 3733 at time 288
# Task assigned to node with CPU power 4062 at time 296
# Task assigned to node with CPU power 4181 at time 296.86582157378615
# Task assigned to node with CPU power 4595 at time 297
# Task assigned to node with CPU power 2523 at time 299
# Task assigned to node with CPU power 2451 at time 300.6585067319461
# Task assigned to node with CPU power 1386 at time 301.01082251082255
# Task assigned to node with CPU power 2478 at time 303.09927360774816
# Task assigned to node with CPU power 1087 at time 304.8371665133395
# Task assigned to node with CPU power 2012 at time 308.4721669980119
# Task assigned to node with CPU power 1593 at time 313.8217200251098
# Task assigned to node with CPU power 2478 at time 320.6335754640839
# Task assigned to node with CPU power 2012 at time 325.27335984095424
# Task assigned to node with CPU power 1087 at time 332.4333026678934
# Task assigned to node with CPU power 1593 at time 336.03327055869426
# Task assigned to node with CPU power 1386 at time 336.11832611832614
# Task assigned to node with CPU power 2012 at time 336.3628230616302
# Task assigned to node with CPU power 2478 at time 342.2122679580306
# Task assigned to node with CPU power 1593 at time 343.1933458882611
# Task assigned to node with CPU power 1593 at time 347.8330194601381
# Task assigned to node with CPU power 1087 at time 357.0625574977002
# Task assigned to node with CPU power 2012 at time 362.12326043737573
# Task assigned to node with CPU power 1386 at time 366.9155844155844
# Task assigned to node with CPU power 2012 at time 379.1003976143141
# Task assigned to node with CPU power 1386 at time 387.91630591630593
# Task assigned to node with CPU power 2012 at time 388.1660039761431
# Task assigned to node with CPU power 1386 at time 424.2799422799423
# Task assigned to node with CPU power 1386 at time 462.8694083694084
# Task assigned to node with CPU power 1386 at time 485.95238095238096
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 60, in generate_tasks(env, nodes, task_length_range, data_size_range, num_tasks, task_allocation)
#      59 data_size = random.randint(*data_size_range)
# ---> 60 node = nodes[task_allocation[task_id]]
#      61 task_start_times.append(env.now)
#
# TypeError: list indices must be integers or slices, not numpy.float64
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 155
#     152         print(f"Total energy consumption for {num_tasks} tasks: {result['energy_consumption']}")
#     154 if __name__ == "__main__":
# --> 155     main()
#
# Cell In[11], line 129, in main()
#     126 num_iterations = 500
#     128 for num_tasks in TASK_SETS:
# --> 129     gbest_position, gbest_score = qpso_optimize(num_particles, num_iterations, num_tasks, CLOUD_NODES + FOG_NODES)
#     131     env = simpy.Environment()
#     132     cloud_nodes = [
#     133         Node(env, random.randint(*CLOUD_CPU_POWER), CLOUD_RAM, CLOUD_STORAGE, CLOUD_BANDWIDTH)
#     134         for _ in range(CLOUD_NODES)
#     135     ]
#
# Cell In[11], line 105, in qpso_optimize(num_particles, num_iterations, num_tasks, num_nodes)
#      99 fog_nodes = [
#     100     Node(env, random.randint(*FOG_CPU_POWER), FOG_RAM, FOG_STORAGE, FOG_BANDWIDTH)
#     101     for _ in range(FOG_NODES)
#     102 ]
#     103 all_nodes = cloud_nodes + fog_nodes
# --> 105 makespan, energy_consumption = fitness_function(env, all_nodes, num_tasks, particles[i])
#     106 score = makespan + energy_consumption
#     108 if score < pbest_scores[i]:
#
# Cell In[11], line 79, in fitness_function(env, all_nodes, num_tasks, task_allocation)
#      77 def fitness_function(env, all_nodes, num_tasks, task_allocation):
#      78     makespan = env.process(generate_tasks(env, all_nodes, TASK_LENGTH, DATA_SIZE, num_tasks, task_allocation))
# ---> 79     env.run()
#      80     makespan = makespan.value
#      81     total_energy_consumption = sum(node.calculate_energy_consumption(makespan) for node in all_nodes)
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpy\core.py:254, in Environment.run(self, until)
#     252 try:
#     253     while True:
# --> 254         self.step()
#     255 except StopSimulation as exc:
#     256     return exc.args[0]  # == until.value
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpy\core.py:206, in Environment.step(self)
#     204 exc = type(event._value)(*event._value.args)
#     205 exc.__cause__ = event._value
# --> 206 raise exc
#
# TypeError: list indices must be integers or slices, not numpy.float64
