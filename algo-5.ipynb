# %%
import simpy
import random
import numpy as np

# Define constants based on the provided parameters
NUM_CLIENTS = random.randint(100, 200)
NUM_DATACENTERS = 1
NUM_HOSTS = 2

# Cloud node parameters
CLOUD_NODES = 10
CLOUD_CPU_POWER = (3000, 5000)  # MIPS
CLOUD_RAM = 8  # GB
CLOUD_STORAGE = 1  # TB
CLOUD_BANDWIDTH = 0.5  # Gb/s

# Fog node parameters
FOG_NODES = 10
FOG_CPU_POWER = (1000, 2800)  # MIPS
FOG_RAM = 2  # GB
FOG_STORAGE = 0.5  # TB
FOG_BANDWIDTH = 1  # Gb/s

# Task parameters
TASK_LENGTH = (2000, 56000)  # MI
DATA_SIZE = (400, 600)  # MB
TASK_SETS = [300, 600, 900, 1200, 1500]  # Different sets of task numbers

class Node:
    def __init__(self, env, cpu_power, ram, storage, bandwidth):
        self.env = env
        self.cpu_power = cpu_power
        self.ram = ram
        self.storage = storage
        self.bandwidth = bandwidth
        self.queue = simpy.Resource(env, capacity=1)
        self.total_execution_time = 0

    def process_task(self, task_length, data_size):
        # Processing time is based on task length and CPU power
        processing_time = task_length / self.cpu_power
        self.total_execution_time += processing_time
        yield self.env.timeout(processing_time)

    def calculate_energy_consumption(self, makespan):
        beta_j = 10**-8 * self.cpu_power**2
        alpha_j = 0.6 * beta_j
        active_energy = self.total_execution_time * beta_j
        idle_energy = (makespan - self.total_execution_time) * alpha_j
        total_energy = active_energy + idle_energy
        return total_energy

def generate_tasks(env, nodes, task_length_range, data_size_range, num_tasks, task_allocation):
    task_start_times = []
    task_end_times = []
    
    for task_id in range(num_tasks):
        task_length = random.randint(*task_length_range)
        data_size = random.randint(*data_size_range)
        node_index = int(task_allocation[task_id])  # Convert to integer
        node_index = min(max(node_index, 0), len(nodes) - 1)  # Ensure index is within range
        node = nodes[node_index]
        task_start_times.append(env.now)
        env.process(handle_task(env, node, task_length, data_size, task_end_times))
        yield env.timeout(1)  # Small delay to simulate task arrival interval
    
    yield env.timeout(0)  # Yield control to allow all tasks to be processed
    yield env.all_of([env.timeout(1) for _ in range(num_tasks)])  # Wait for all tasks to be completed
    makespan = max(task_end_times) - min(task_start_times)
    return makespan

def handle_task(env, node, task_length, data_size, task_end_times):
    with node.queue.request() as request:
        yield request
        print(f"Task assigned to node with CPU power {node.cpu_power} at time {env.now}")
        yield env.process(node.process_task(task_length, data_size))
        task_end_times.append(env.now)

def fitness_function(env, all_nodes, num_tasks, task_allocation):
    makespan = env.process(generate_tasks(env, all_nodes, TASK_LENGTH, DATA_SIZE, num_tasks, task_allocation))
    env.run()
    makespan = makespan.value
    total_energy_consumption = sum(node.calculate_energy_consumption(makespan) for node in all_nodes)
    return makespan, total_energy_consumption

def qpso_optimize(num_particles, num_iterations, num_tasks, num_nodes):
    # Initialize particles
    particles = np.random.randint(0, num_nodes, (num_particles, num_tasks))
    pbest_positions = particles.copy()
    pbest_scores = np.full(num_particles, np.inf)
    gbest_position = None
    gbest_score = np.inf
    
    for _ in range(num_iterations):
        for i in range(num_particles):
            env = simpy.Environment()
            cloud_nodes = [
                Node(env, random.randint(*CLOUD_CPU_POWER), CLOUD_RAM, CLOUD_STORAGE, CLOUD_BANDWIDTH)
                for _ in range(CLOUD_NODES)
            ]
            fog_nodes = [
                Node(env, random.randint(*FOG_CPU_POWER), FOG_RAM, FOG_STORAGE, FOG_BANDWIDTH)
                for _ in range(FOG_NODES)
            ]
            all_nodes = cloud_nodes + fog_nodes
            
            makespan, energy_consumption = fitness_function(env, all_nodes, num_tasks, particles[i])
            score = makespan + energy_consumption
            
            if score < pbest_scores[i]:
                pbest_scores[i] = score
                pbest_positions[i] = particles[i].copy()
                
            if score < gbest_score:
                gbest_score = score
                gbest_position = particles[i].copy()
        
        mb = np.mean(pbest_positions, axis=0)
        beta = 1.0  # You can adjust this parameter based on your problem
        u = np.random.rand(num_particles, num_tasks)
        particles = mb + beta * np.abs(pbest_positions - particles) * np.log(1.0 / u)
        particles = np.clip(particles, 0, num_nodes - 1).astype(int)  # Ensure particles are within range and integers
        
    return gbest_position, gbest_score

def main():
    results = {}
    num_particles = 30
    num_iterations = 50

    for num_tasks in TASK_SETS:
        gbest_position, gbest_score = qpso_optimize(num_particles, num_iterations, num_tasks, CLOUD_NODES + FOG_NODES)
        
        env = simpy.Environment()
        cloud_nodes = [
            Node(env, random.randint(*CLOUD_CPU_POWER), CLOUD_RAM, CLOUD_STORAGE, CLOUD_BANDWIDTH)
            for _ in range(CLOUD_NODES)
        ]
        fog_nodes = [
            Node(env, random.randint(*FOG_CPU_POWER), FOG_RAM, FOG_STORAGE, FOG_BANDWIDTH)
            for _ in range(FOG_NODES)
        ]
        all_nodes = cloud_nodes + fog_nodes
        
        makespan, energy_consumption = fitness_function(env, all_nodes, num_tasks, gbest_position)
        
        results[num_tasks] = {
            "makespan": makespan,
            "energy_consumption": energy_consumption
        }

    # Output the makespan and energy consumption for each set of tasks
    for num_tasks, result in results.items():
        print(f"Makespan for {num_tasks} tasks: {result['makespan']}")
        print(f"Total energy consumption for {num_tasks} tasks: {result['energy_consumption']}")

if __name__ == "__main__":
    main()
# Out:
# Task assigned to node with CPU power 4060 at time 0
# Task assigned to node with CPU power 1532 at time 1
# Task assigned to node with CPU power 4170 at time 2
# Task assigned to node with CPU power 1347 at time 3
# Task assigned to node with CPU power 1532 at time 4
# Task assigned to node with CPU power 4060 at time 5
# Task assigned to node with CPU power 3441 at time 6
# Task assigned to node with CPU power 1643 at time 7
# Task assigned to node with CPU power 4661 at time 8
# Task assigned to node with CPU power 4479 at time 10
# Task assigned to node with CPU power 3820 at time 11
# Task assigned to node with CPU power 1132 at time 16
# Task assigned to node with CPU power 1532 at time 18.248694516971277
# Task assigned to node with CPU power 4250 at time 19
# Task assigned to node with CPU power 1562 at time 20
# Task assigned to node with CPU power 4250 at time 21
# Task assigned to node with CPU power 4661 at time 22
# Task assigned to node with CPU power 1904 at time 24
# Task assigned to node with CPU power 1643 at time 24.34449178332319
# Task assigned to node with CPU power 1643 at time 26.57273280584297
# Task assigned to node with CPU power 4060 at time 27
# Task assigned to node with CPU power 4437 at time 28
# Task assigned to node with CPU power 1170 at time 30
# Task assigned to node with CPU power 3820 at time 32
# Task assigned to node with CPU power 4250 at time 34
# Task assigned to node with CPU power 4437 at time 34.57606490872211
# Task assigned to node with CPU power 4158 at time 35
# Task assigned to node with CPU power 1904 at time 36
# Task assigned to node with CPU power 4060 at time 38.05221674876847
# Task assigned to node with CPU power 4479 at time 40
# Task assigned to node with CPU power 1347 at time 42.27839643652561
# Task assigned to node with CPU power 1532 at time 42.44190600522193
# Task assigned to node with CPU power 4158 at time 43
# Task assigned to node with CPU power 4437 at time 43.008789722785664
# Task assigned to node with CPU power 4661 at time 44
# Task assigned to node with CPU power 4250 at time 45
# Task assigned to node with CPU power 1562 at time 45.774647887323944
# Task assigned to node with CPU power 1904 at time 46.52153361344538
# Task assigned to node with CPU power 3441 at time 49
# Task assigned to node with CPU power 4479 at time 53
# Task assigned to node with CPU power 4661 at time 53.90881785024673
# Task assigned to node with CPU power 1904 at time 54.03886554621849
# Task assigned to node with CPU power 4060 at time 55
# Task assigned to node with CPU power 1132 at time 55.986749116607776
# Task assigned to node with CPU power 4158 at time 56.32347282347283
# Task assigned to node with CPU power 3820 at time 57
# Task assigned to node with CPU power 4170 at time 58
# Task assigned to node with CPU power 1532 at time 59.85770234986945
# Task assigned to node with CPU power 3441 at time 60.56582388840454
# Task assigned to node with CPU power 1347 at time 61.94654788418708
# Task assigned to node with CPU power 4661 at time 63
# Task assigned to node with CPU power 4158 at time 64
# Task assigned to node with CPU power 4479 at time 67
# Task assigned to node with CPU power 3820 at time 67.00811518324608
# Task assigned to node with CPU power 4661 at time 68
# Task assigned to node with CPU power 3441 at time 70.83551293228713
# Task assigned to node with CPU power 1347 at time 71.16629547141797
# Task assigned to node with CPU power 4158 at time 72
# Task assigned to node with CPU power 2770 at time 73
# Task assigned to node with CPU power 1459 at time 74
# Task assigned to node with CPU power 1562 at time 74.97311139564661
# Task assigned to node with CPU power 1170 at time 76
# Task assigned to node with CPU power 1347 at time 76.48849294729028
# Task assigned to node with CPU power 1532 at time 77.55221932114883
# Task assigned to node with CPU power 4661 at time 78.61016949152543
# Task assigned to node with CPU power 3820 at time 80
# Task assigned to node with CPU power 1904 at time 82.28939075630252
# Task assigned to node with CPU power 1643 at time 84
# Task assigned to node with CPU power 3441 at time 84.5207788433595
# Task assigned to node with CPU power 1532 at time 85.24281984334203
# Task assigned to node with CPU power 1562 at time 85.25032010243278
# Task assigned to node with CPU power 3820 at time 85.43507853403142
# Task assigned to node with CPU power 1622 at time 87
# Task assigned to node with CPU power 2770 at time 89
# Task assigned to node with CPU power 3820 at time 93.6801047120419
# Task assigned to node with CPU power 3441 at time 93.77651845393781
# Task assigned to node with CPU power 1170 at time 94
# Task assigned to node with CPU power 2770 at time 94.014440433213
# Task assigned to node with CPU power 1347 at time 94.98144023756497
# Task assigned to node with CPU power 1622 at time 97
# Task assigned to node with CPU power 1459 at time 99.46470185058259
# Task assigned to node with CPU power 4437 at time 100
# Task assigned to node with CPU power 1347 at time 101.96807720861173
# Task assigned to node with CPU power 4334 at time 102
# Task assigned to node with CPU power 1562 at time 102.24327784891165
# Task assigned to node with CPU power 1904 at time 103
# Task assigned to node with CPU power 4158 at time 104
# Task assigned to node with CPU power 1132 at time 104.30742049469964
# Task assigned to node with CPU power 1347 at time 104.84409799554565
# Task assigned to node with CPU power 3820 at time 107.06230366492147
# Task assigned to node with CPU power 4334 at time 108
# Task assigned to node with CPU power 1347 at time 108.08017817371937
# Task assigned to node with CPU power 1643 at time 109.57334144856969
# Task assigned to node with CPU power 4661 at time 110
# Task assigned to node with CPU power 4661 at time 112.77966101694915
# Task assigned to node with CPU power 1904 at time 114
# Task assigned to node with CPU power 4170 at time 116
# Task assigned to node with CPU power 1532 at time 116.7056135770235
# Task assigned to node with CPU power 1532 at time 118.53655352480418
# Task assigned to node with CPU power 1170 at time 118.7008547008547
# Task assigned to node with CPU power 3441 at time 119
# Task assigned to node with CPU power 4661 at time 120.84488307230208
# Task assigned to node with CPU power 4170 at time 124.61606714628297
# Task assigned to node with CPU power 2770 at time 125
# Task assigned to node with CPU power 4479 at time 126
# Task assigned to node with CPU power 4170 at time 126.20431654676258
# Task assigned to node with CPU power 1170 at time 130.30598290598292
# Task assigned to node with CPU power 4661 at time 131.5606093113066
# Task assigned to node with CPU power 1562 at time 131.76248399487835
# Task assigned to node with CPU power 4158 at time 132
# Task assigned to node with CPU power 4170 at time 132.3822541966427
# Task assigned to node with CPU power 4250 at time 133
# Task assigned to node with CPU power 1459 at time 133.42837559972583
# Task assigned to node with CPU power 1562 at time 133.90524967989757
# Task assigned to node with CPU power 2770 at time 134
# Task assigned to node with CPU power 1347 at time 134.12694877505567
# Task assigned to node with CPU power 1532 at time 134.32310704960835
# Task assigned to node with CPU power 4661 at time 136
# Task assigned to node with CPU power 1643 at time 138.07608034083992
# Task assigned to node with CPU power 4250 at time 138.19576470588234
# Task assigned to node with CPU power 1347 at time 138.43949517446174
# Task assigned to node with CPU power 1132 at time 138.93904593639576
# Task assigned to node with CPU power 1622 at time 139
# Task assigned to node with CPU power 1132 at time 140.76766784452298
# Task assigned to node with CPU power 3441 at time 141
# Task assigned to node with CPU power 2770 at time 144.0158844765343
# Task assigned to node with CPU power 4170 at time 144.24676258992807
# Task assigned to node with CPU power 4250 at time 146
# Task assigned to node with CPU power 4060 at time 147
# Task assigned to node with CPU power 3820 at time 149
# Task assigned to node with CPU power 1170 at time 150.44529914529915
# Task assigned to node with CPU power 4170 at time 152.46211031175062
# Task assigned to node with CPU power 3820 at time 153
# Task assigned to node with CPU power 4158 at time 154
# Task assigned to node with CPU power 4060 at time 154.36724137931034
# Task assigned to node with CPU power 1643 at time 154.75958612294582
# Task assigned to node with CPU power 4334 at time 156
# Task assigned to node with CPU power 4170 at time 156.9486810551559
# Task assigned to node with CPU power 2770 at time 158.88447653429603
# Task assigned to node with CPU power 1532 at time 160
# Task assigned to node with CPU power 4170 at time 160.2496402877698
# Task assigned to node with CPU power 4250 at time 162
# Task assigned to node with CPU power 4158 at time 163
# Task assigned to node with CPU power 4334 at time 164
# Task assigned to node with CPU power 4437 at time 165
# Task assigned to node with CPU power 1622 at time 165.27127003699138
# Task assigned to node with CPU power 1347 at time 166.8715664439495
# Task assigned to node with CPU power 1132 at time 167
# Task assigned to node with CPU power 1562 at time 167.1338028169014
# Task assigned to node with CPU power 1459 at time 167.52501713502397
# Task assigned to node with CPU power 4250 at time 171.96682352941176
# Task assigned to node with CPU power 4170 at time 172.95035971223024
# Task assigned to node with CPU power 4661 at time 173
# Task assigned to node with CPU power 3441 at time 174
# Task assigned to node with CPU power 1643 at time 174.44613511868533
# Task assigned to node with CPU power 4437 at time 175.48005409060175
# Task assigned to node with CPU power 3820 at time 176
# Task assigned to node with CPU power 2770 at time 180
# Task assigned to node with CPU power 4170 at time 182
# Task assigned to node with CPU power 1170 at time 182.9794871794872
# Task assigned to node with CPU power 1622 at time 183.48890258939582
# Task assigned to node with CPU power 2770 at time 183.91949458483754
# Task assigned to node with CPU power 1562 at time 185.16709346991036
# Task assigned to node with CPU power 4479 at time 187
# Task assigned to node with CPU power 1622 at time 187.2589395807645
# Task assigned to node with CPU power 3820 at time 189.64476439790576
# Task assigned to node with CPU power 4334 at time 191
# Task assigned to node with CPU power 4060 at time 193
# Task assigned to node with CPU power 1562 at time 193.13188220230472
# Task assigned to node with CPU power 1170 at time 194.44529914529915
# Task assigned to node with CPU power 4170 at time 194.69304556354916
# Task assigned to node with CPU power 3441 at time 196
# Task assigned to node with CPU power 1459 at time 196.10006854009595
# Task assigned to node with CPU power 1347 at time 198.81811432813657
# Task assigned to node with CPU power 1904 at time 200
# Task assigned to node with CPU power 1904 at time 202.41649159663865
# Task assigned to node with CPU power 4170 at time 203.74868105515588
# Task assigned to node with CPU power 1643 at time 204.7303712720633
# Task assigned to node with CPU power 1132 at time 205.70318021201413
# Task assigned to node with CPU power 3820 at time 207
# Task assigned to node with CPU power 4334 at time 208
# Task assigned to node with CPU power 1532 at time 210
# Task assigned to node with CPU power 1459 at time 212.1590130226182
# Task assigned to node with CPU power 4661 at time 213
# Task assigned to node with CPU power 1562 at time 214.12291933418692
# Task assigned to node with CPU power 4479 at time 217
# Task assigned to node with CPU power 4170 at time 218
# Task assigned to node with CPU power 1622 at time 218.40073982737363
# Task assigned to node with CPU power 1347 at time 218.63697104677058
# Task assigned to node with CPU power 1170 at time 221.4025641025641
# Task assigned to node with CPU power 4158 at time 222
# Task assigned to node with CPU power 1643 at time 222.7048082775411
# Task assigned to node with CPU power 4437 at time 223
# Task assigned to node with CPU power 1904 at time 223.78623949579833
# Task assigned to node with CPU power 4479 at time 224.4454119223041
# Task assigned to node with CPU power 1643 at time 230.2373706634206
# Task assigned to node with CPU power 1532 at time 231.01827676240208
# Task assigned to node with CPU power 1132 at time 231.63957597173146
# Task assigned to node with CPU power 4060 at time 232
# Task assigned to node with CPU power 1170 at time 297.5700854700855
# Task assigned to node with CPU power 1622 at time 298.63131935881626
# Task assigned to node with CPU power 1643 at time 299.72245891661595
# Task assigned to node with CPU power 1643 at time 312.338405356056
# Task assigned to node with CPU power 1132 at time 315.2897526501767
# Task assigned to node with CPU power 1562 at time 315.9065300896287
# Task assigned to node with CPU power 1347 at time 318.6080178173719
# Task assigned to node with CPU power 1459 at time 320.759424263194
# Task assigned to node with CPU power 1643 at time 322.77541083384057
# Task assigned to node with CPU power 1459 at time 327.53598355037695
# Task assigned to node with CPU power 1532 at time 328.96540469973894
# Task assigned to node with CPU power 1170 at time 331.53675213675217
# Task assigned to node with CPU power 1622 at time 332.08384710234276
# Task assigned to node with CPU power 1459 at time 337.78478409869774
# Task assigned to node with CPU power 1170 at time 340.7957264957265
# Task assigned to node with CPU power 1562 at time 345.64980793854033
# Task assigned to node with CPU power 1347 at time 351.7572383073496
# Task assigned to node with CPU power 1347 at time 353.71046770601333
# Task assigned to node with CPU power 1132 at time 354.3242049469965
# Task assigned to node with CPU power 1643 at time 356.1326841144249
# Task assigned to node with CPU power 1459 at time 358.6415352981494
# Task assigned to node with CPU power 1562 at time 366.2304737516005
# Task assigned to node with CPU power 1132 at time 374.60689045936397
# Task assigned to node with CPU power 1170 at time 380.165811965812
# Task assigned to node with CPU power 1643 at time 382.4503956177724
# Task assigned to node with CPU power 1562 at time 390.4411011523688
# Task assigned to node with CPU power 1459 at time 391.3831391363948
# Task assigned to node with CPU power 1459 at time 395.76901987662785
# Task assigned to node with CPU power 1562 at time 395.8943661971831
# Task assigned to node with CPU power 1459 at time 398.9897189856066
# Task assigned to node with CPU power 1170 at time 401.2102564102564
# Task assigned to node with CPU power 1459 at time 405.9252912954078
# Task assigned to node with CPU power 1562 at time 408.50640204865556
# Task assigned to node with CPU power 1643 at time 409.58734023128426
# Task assigned to node with CPU power 1562 at time 413.98015364916773
# Task assigned to node with CPU power 1643 at time 423.4930006086428
# Task assigned to node with CPU power 1562 at time 436.1024327784891
# Task assigned to node with CPU power 1170 at time 439.20085470085473
# Task assigned to node with CPU power 1170 at time 453.3478632478633
# Task assigned to node with CPU power 1170 at time 470.5282051282052
# Task assigned to node with CPU power 1170 at time 488.7521367521368
# Task assigned to node with CPU power 2624 at time 0
# Task assigned to node with CPU power 2669 at time 1
# Task assigned to node with CPU power 4771 at time 2
# Task assigned to node with CPU power 4195 at time 3
# Task assigned to node with CPU power 3200 at time 4
# Task assigned to node with CPU power 2642 at time 5
# Task assigned to node with CPU power 3823 at time 7
# Task assigned to node with CPU power 3366 at time 8
# Task assigned to node with CPU power 4195 at time 8.395709177592373
# Task assigned to node with CPU power 3119 at time 9
# Task assigned to node with CPU power 2148 at time 11
# Task assigned to node with CPU power 3200 at time 12.760625
# Task assigned to node with CPU power 4712 at time 13
# Task assigned to node with CPU power 1495 at time 14
# Task assigned to node with CPU power 3948 at time 15
# Task assigned to node with CPU power 1780 at time 16
# Task assigned to node with CPU power 4195 at time 18.35113230035757
# Task assigned to node with CPU power 3823 at time 19
# Task assigned to node with CPU power 2148 at time 20
# Task assigned to node with CPU power 2642 at time 20.9220287660863
# Task assigned to node with CPU power 3948 at time 21
# Task assigned to node with CPU power 1839 at time 23
# Task assigned to node with CPU power 4540 at time 24
# Task assigned to node with CPU power 1330 at time 25
# Task assigned to node with CPU power 3119 at time 25.965373517152933
# Task assigned to node with CPU power 3366 at time 27
# Task assigned to node with CPU power 4771 at time 30
# Task assigned to node with CPU power 1839 at time 30.02120717781403
# Task assigned to node with CPU power 3366 at time 31.8184789067142
# Task assigned to node with CPU power 4195 at time 32
# Task assigned to node with CPU power 3823 at time 32.94873136280408
# Task assigned to node with CPU power 2669 at time 33
# Task assigned to node with CPU power 2624 at time 35
# Task assigned to node with CPU power 4540 at time 36
# Task assigned to node with CPU power 4712 at time 37
# Task assigned to node with CPU power 2642 at time 37.699091597274794
# Task assigned to node with CPU power 3948 at time 38
# Task assigned to node with CPU power 3366 at time 39
# Task assigned to node with CPU power 1983 at time 40
# Task assigned to node with CPU power 3823 at time 42.819513471096
# Task assigned to node with CPU power 3119 at time 45
# Task assigned to node with CPU power 4195 at time 45.02574493444577
# Task assigned to node with CPU power 2148 at time 46
# Task assigned to node with CPU power 1983 at time 46.29803328290469
# Task assigned to node with CPU power 1831 at time 47
# Task assigned to node with CPU power 2624 at time 48
# Task assigned to node with CPU power 4712 at time 49
# Task assigned to node with CPU power 3948 at time 50.43414387031408
# Task assigned to node with CPU power 1330 at time 52.03533834586466
# Task assigned to node with CPU power 3119 at time 54.049374799615265
# Task assigned to node with CPU power 2642 at time 54.15745647236942
# Task assigned to node with CPU power 3200 at time 57
# Task assigned to node with CPU power 1831 at time 57.584926269797926
# Task assigned to node with CPU power 3200 at time 58.4778125
# Task assigned to node with CPU power 1839 at time 58.72920065252855
# Task assigned to node with CPU power 1495 at time 59
# Task assigned to node with CPU power 4712 at time 59.38455008488964
# Task assigned to node with CPU power 1839 at time 59.88907014681892
# Task assigned to node with CPU power 4195 at time 60
# Task assigned to node with CPU power 3200 at time 62
# Task assigned to node with CPU power 4260 at time 66
# Task assigned to node with CPU power 3948 at time 68
# Task assigned to node with CPU power 2669 at time 70
# Task assigned to node with CPU power 2148 at time 71
# Task assigned to node with CPU power 1983 at time 71.69238527483611
# Task assigned to node with CPU power 2642 at time 72.4004542013626
# Task assigned to node with CPU power 3366 at time 73
# Task assigned to node with CPU power 1495 at time 73.07692307692308
# Task assigned to node with CPU power 2624 at time 76
# Task assigned to node with CPU power 3948 at time 80.91388044579534
# Task assigned to node with CPU power 1839 at time 82.22022838499184
# Task assigned to node with CPU power 4260 at time 83
# Task assigned to node with CPU power 1831 at time 83.28235936646641
# Task assigned to node with CPU power 4712 at time 84
# Task assigned to node with CPU power 3200 at time 85
# Task assigned to node with CPU power 3366 at time 88
# Task assigned to node with CPU power 1330 at time 89.0421052631579
# Task assigned to node with CPU power 4540 at time 90
# Task assigned to node with CPU power 1983 at time 92.7927382753404
# Task assigned to node with CPU power 3823 at time 93
# Task assigned to node with CPU power 1839 at time 93.33224578575313
# Task assigned to node with CPU power 4771 at time 94
# Task assigned to node with CPU power 4540 at time 95
# Task assigned to node with CPU power 2148 at time 95.4082867783985
# Task assigned to node with CPU power 3119 at time 96
# Task assigned to node with CPU power 3200 at time 96.4934375
# Task assigned to node with CPU power 3948 at time 99
# Task assigned to node with CPU power 1831 at time 100.67012561441834
# Task assigned to node with CPU power 2624 at time 101
# Task assigned to node with CPU power 3823 at time 102
# Task assigned to node with CPU power 1330 at time 103.86315789473684
# Task assigned to node with CPU power 4195 at time 104
# Task assigned to node with CPU power 3200 at time 107.1296875
# Task assigned to node with CPU power 3119 at time 107.95158704713049
# Task assigned to node with CPU power 2624 at time 108
# Task assigned to node with CPU power 1495 at time 108.72575250836121
# Task assigned to node with CPU power 1780 at time 109
# Task assigned to node with CPU power 1330 at time 111.79849624060151
# Task assigned to node with CPU power 3948 at time 111.91489361702128
# Task assigned to node with CPU power 4540 at time 112
# Task assigned to node with CPU power 3823 at time 112.56421658383468
# Task assigned to node with CPU power 3366 at time 113
# Task assigned to node with CPU power 1983 at time 113.72970247100353
# Task assigned to node with CPU power 2642 at time 115
# Task assigned to node with CPU power 3948 at time 118
# Task assigned to node with CPU power 1780 at time 118.88426966292135
# Task assigned to node with CPU power 2642 at time 120
# Task assigned to node with CPU power 2148 at time 122
# Task assigned to node with CPU power 3948 at time 122.06534954407294
# Task assigned to node with CPU power 4540 at time 122.9398678414097
# Task assigned to node with CPU power 4712 at time 123
# Task assigned to node with CPU power 3200 at time 123.6025
# Task assigned to node with CPU power 1831 at time 124.96996176952484
# Task assigned to node with CPU power 3366 at time 125
# Task assigned to node with CPU power 2669 at time 126
# Task assigned to node with CPU power 3823 at time 127
# Task assigned to node with CPU power 3119 at time 128
# Task assigned to node with CPU power 1330 at time 132.1827067669173
# Task assigned to node with CPU power 4540 at time 132.415859030837
# Task assigned to node with CPU power 4712 at time 132.70649405772497
# Task assigned to node with CPU power 4260 at time 133
# Task assigned to node with CPU power 3200 at time 133.7603125
# Task assigned to node with CPU power 4712 at time 134.4772920203735
# Task assigned to node with CPU power 3823 at time 134.51294794663877
# Task assigned to node with CPU power 3119 at time 135
# Task assigned to node with CPU power 3366 at time 136
# Task assigned to node with CPU power 1330 at time 136.506015037594
# Task assigned to node with CPU power 4195 at time 137
# Task assigned to node with CPU power 1330 at time 139.8729323308271
# Task assigned to node with CPU power 2642 at time 140
# Task assigned to node with CPU power 1839 at time 141
# Task assigned to node with CPU power 1831 at time 143.35827416712178
# Task assigned to node with CPU power 2624 at time 144
# Task assigned to node with CPU power 2669 at time 144.0917946796553
# Task assigned to node with CPU power 3823 at time 144.17996337954486
# Task assigned to node with CPU power 1495 at time 144.81471571906354
# Task assigned to node with CPU power 1780 at time 145
# Task assigned to node with CPU power 4771 at time 146
# Task assigned to node with CPU power 3200 at time 148.3975
# Task assigned to node with CPU power 3366 at time 150.4997029114676
# Task assigned to node with CPU power 3948 at time 151
# Task assigned to node with CPU power 3200 at time 152
# Task assigned to node with CPU power 4195 at time 153
# Task assigned to node with CPU power 2642 at time 154
# Task assigned to node with CPU power 4260 at time 156
# Task assigned to node with CPU power 1831 at time 156.39486619333695
# Task assigned to node with CPU power 3119 at time 158
# Task assigned to node with CPU power 1780 at time 159.1556179775281
# Task assigned to node with CPU power 3948 at time 159.70592705167172
# Task assigned to node with CPU power 2642 at time 160
# Task assigned to node with CPU power 3948 at time 161
# Task assigned to node with CPU power 3366 at time 162
# Task assigned to node with CPU power 3200 at time 164
# Task assigned to node with CPU power 2148 at time 165
# Task assigned to node with CPU power 1495 at time 167.06354515050168
# Task assigned to node with CPU power 4712 at time 168
# Task assigned to node with CPU power 3119 at time 168.54697018275087
# Task assigned to node with CPU power 4540 at time 169
# Task assigned to node with CPU power 2642 at time 170
# Task assigned to node with CPU power 4771 at time 171
# Task assigned to node with CPU power 4712 at time 174
# Task assigned to node with CPU power 3948 at time 175.1015704154002
# Task assigned to node with CPU power 1780 at time 175.6814606741573
# Task assigned to node with CPU power 1839 at time 176
# Task assigned to node with CPU power 1983 at time 177
# Task assigned to node with CPU power 3823 at time 178
# Task assigned to node with CPU power 4260 at time 179
# Task assigned to node with CPU power 4712 at time 182.00742784380304
# Task assigned to node with CPU power 2642 at time 183
# Task assigned to node with CPU power 2669 at time 184
# Task assigned to node with CPU power 1330 at time 185
# Task assigned to node with CPU power 3823 at time 186
# Task assigned to node with CPU power 1831 at time 186.78154014199887
# Task assigned to node with CPU power 3948 at time 187.38145896656536
# Task assigned to node with CPU power 1330 at time 187.99022556390977
# Task assigned to node with CPU power 3200 at time 188
# Task assigned to node with CPU power 4260 at time 189.57089201877935
# Task assigned to node with CPU power 4771 at time 190
# Task assigned to node with CPU power 3366 at time 192
# Task assigned to node with CPU power 1330 at time 193
# Task assigned to node with CPU power 3119 at time 194
# Task assigned to node with CPU power 1780 at time 195.1505617977528
# Task assigned to node with CPU power 4540 at time 196
# Task assigned to node with CPU power 2669 at time 196.1502435369052
# Task assigned to node with CPU power 1495 at time 197.41672240802677
# Task assigned to node with CPU power 1839 at time 198.8510059815117
# Task assigned to node with CPU power 3948 at time 201
# Task assigned to node with CPU power 3119 at time 202
# Task assigned to node with CPU power 4260 at time 203
# Task assigned to node with CPU power 3366 at time 204.26351752822342
# Task assigned to node with CPU power 3200 at time 205
# Task assigned to node with CPU power 1831 at time 205.3648279628618
# Task assigned to node with CPU power 4771 at time 207
# Task assigned to node with CPU power 4540 at time 208.1215859030837
# Task assigned to node with CPU power 3366 at time 209
# Task assigned to node with CPU power 4260 at time 209.48779342723006
# Task assigned to node with CPU power 2669 at time 210.78793555638816
# Task assigned to node with CPU power 1780 at time 210.90786516853933
# Task assigned to node with CPU power 2642 at time 211
# Task assigned to node with CPU power 1780 at time 212.24550561797753
# Task assigned to node with CPU power 3823 at time 213
# Task assigned to node with CPU power 1330 at time 216.5609022556391
# Task assigned to node with CPU power 1983 at time 278.4583963691377
# Task assigned to node with CPU power 3366 at time 279
# Task assigned to node with CPU power 3200 at time 280.183125
# Task assigned to node with CPU power 3119 at time 281.19012504007696
# Task assigned to node with CPU power 1839 at time 282.56824361065793
# Task assigned to node with CPU power 1495 at time 284.494983277592
# Task assigned to node with CPU power 1780 at time 285
# Task assigned to node with CPU power 4712 at time 286
# Task assigned to node with CPU power 4771 at time 286.574931880109
# Task assigned to node with CPU power 2669 at time 287
# Task assigned to node with CPU power 4540 at time 288
# Task assigned to node with CPU power 3823 at time 289
# Task assigned to node with CPU power 3948 at time 289.69908814589667
# Task assigned to node with CPU power 3200 at time 291.3159375
# Task assigned to node with CPU power 3366 at time 291.801247771836
# Task assigned to node with CPU power 4260 at time 294
# Task assigned to node with CPU power 3823 at time 294.45513994245357
# Task assigned to node with CPU power 3948 at time 297
# Task assigned to node with CPU power 3119 at time 297.41295286950947
# Task assigned to node with CPU power 1831 at time 297.5144729655926
# Task assigned to node with CPU power 2624 at time 298
# Task assigned to node with CPU power 2148 at time 299.1731843575419
# Task assigned to node with CPU power 1839 at time 299.6992930940728
# Task assigned to node with CPU power 3200 at time 301.3459375
# Task assigned to node with CPU power 1983 at time 301.44881492687847
# Task assigned to node with CPU power 1831 at time 303.61168760240304
# Task assigned to node with CPU power 2669 at time 304.52416635443984
# Task assigned to node with CPU power 3119 at time 305.37287592176983
# Task assigned to node with CPU power 1495 at time 308.4628762541806
# Task assigned to node with CPU power 3119 at time 308.5210003206156
# Task assigned to node with CPU power 3200 at time 312.0025
# Task assigned to node with CPU power 1839 at time 321.4834148994018
# Task assigned to node with CPU power 3200 at time 325.7978125
# Task assigned to node with CPU power 1495 at time 338.2494983277592
# Task assigned to node with CPU power 1495 at time 356.7103678929766
# Task assigned to node with CPU power 1495 at time 380.23678929765885
# Task assigned to node with CPU power 1495 at time 417.09096989966554
# Task assigned to node with CPU power 1495 at time 443.2020066889632
# Task assigned to node with CPU power 1567 at time 0
# Task assigned to node with CPU power 1249 at time 1
# Task assigned to node with CPU power 2792 at time 2
# Task assigned to node with CPU power 1587 at time 3
# Task assigned to node with CPU power 3626 at time 4
# Task assigned to node with CPU power 4180 at time 5
# Task assigned to node with CPU power 4590 at time 7
# Task assigned to node with CPU power 1021 at time 8
# Task assigned to node with CPU power 2599 at time 9
# Task assigned to node with CPU power 4180 at time 9.543062200956939
# Task assigned to node with CPU power 3042 at time 10
# Task assigned to node with CPU power 2040 at time 12
# Task assigned to node with CPU power 2792 at time 12.654727793696274
# Task assigned to node with CPU power 3518 at time 13
# Task assigned to node with CPU power 4206 at time 14
# Task assigned to node with CPU power 1556 at time 15
# Task assigned to node with CPU power 4374 at time 22
# Task assigned to node with CPU power 3626 at time 25
# Task assigned to node with CPU power 3042 at time 25.337278106508876
# Task assigned to node with CPU power 4439 at time 26
# Task assigned to node with CPU power 2792 at time 26.05336676217765
# Task assigned to node with CPU power 3353 at time 27
# Task assigned to node with CPU power 1567 at time 29
# Task assigned to node with CPU power 1539 at time 30
# Task assigned to node with CPU power 3042 at time 31.50131492439185
# Task assigned to node with CPU power 4374 at time 32.28852309099223
# Task assigned to node with CPU power 3054 at time 33
# Task assigned to node with CPU power 2040 at time 34.127450980392155
# Task assigned to node with CPU power 1587 at time 34.79332073093887
# Task assigned to node with CPU power 3042 at time 35.756410256410255
# Task assigned to node with CPU power 2599 at time 36
# Task assigned to node with CPU power 3626 at time 37
# Task assigned to node with CPU power 1249 at time 38.020816653322655
# Task assigned to node with CPU power 1865 at time 40
# Task assigned to node with CPU power 3042 at time 41.72748191978961
# Task assigned to node with CPU power 2040 at time 41.877450980392155
# Task assigned to node with CPU power 4206 at time 42
# Task assigned to node with CPU power 1539 at time 43
# Task assigned to node with CPU power 4590 at time 45
# Task assigned to node with CPU power 2792 at time 45.62643266475645
# Task assigned to node with CPU power 4206 at time 46.096528768426055
# Task assigned to node with CPU power 1556 at time 47
# Task assigned to node with CPU power 3054 at time 49.96332678454486
# Task assigned to node with CPU power 3518 at time 50
# Task assigned to node with CPU power 2040 at time 51.21470588235294
# Task assigned to node with CPU power 1567 at time 52.649649010848755
# Task assigned to node with CPU power 3054 at time 54.71152586771448
# Task assigned to node with CPU power 1865 at time 55.055227882037535
# Task assigned to node with CPU power 1249 at time 55.38030424339471
# Task assigned to node with CPU power 2599 at time 57
# Task assigned to node with CPU power 4206 at time 58
# Task assigned to node with CPU power 2792 at time 60
# Task assigned to node with CPU power 3054 at time 60.42796332678455
# Task assigned to node with CPU power 1567 at time 61.79706445437141
# Task assigned to node with CPU power 4180 at time 62
# Task assigned to node with CPU power 3042 at time 64
# Task assigned to node with CPU power 1587 at time 64.05545053560176
# Task assigned to node with CPU power 2599 at time 65
# Task assigned to node with CPU power 3518 at time 66
# Task assigned to node with CPU power 2040 at time 66.40098039215685
# Task assigned to node with CPU power 1556 at time 67
# Task assigned to node with CPU power 4206 at time 68
# Task assigned to node with CPU power 3518 at time 69
# Task assigned to node with CPU power 1539 at time 69.96751137102015
# Task assigned to node with CPU power 3518 at time 71.68988061398522
# Task assigned to node with CPU power 3042 at time 72
# Task assigned to node with CPU power 4180 at time 72.13421052631578
# Task assigned to node with CPU power 1021 at time 74
# Task assigned to node with CPU power 4206 at time 75
# Task assigned to node with CPU power 2599 at time 75.07541362062332
# Task assigned to node with CPU power 4374 at time 77
# Task assigned to node with CPU power 1567 at time 77.07721761327377
# Task assigned to node with CPU power 1865 at time 77.59624664879357
# Task assigned to node with CPU power 1587 at time 78
# Task assigned to node with CPU power 3353 at time 79
# Task assigned to node with CPU power 4590 at time 80
# Task assigned to node with CPU power 3042 at time 82
# Task assigned to node with CPU power 2599 at time 83
# Task assigned to node with CPU power 3353 at time 85.59916492693111
# Task assigned to node with CPU power 2792 at time 86
# Task assigned to node with CPU power 3042 at time 86.22386587771203
# Task assigned to node with CPU power 3518 at time 87
# Task assigned to node with CPU power 1539 at time 90
# Task assigned to node with CPU power 1556 at time 90.7146529562982
# Task assigned to node with CPU power 3054 at time 91
# Task assigned to node with CPU power 2792 at time 92.81661891117479
# Task assigned to node with CPU power 1567 at time 93.03254626675175
# Task assigned to node with CPU power 1249 at time 93.60768614891913
# Task assigned to node with CPU power 1587 at time 94
# Task assigned to node with CPU power 4590 at time 95
# Task assigned to node with CPU power 4374 at time 96
# Task assigned to node with CPU power 4590 at time 98
# Task assigned to node with CPU power 1556 at time 100.54755784061696
# Task assigned to node with CPU power 4180 at time 101
# Task assigned to node with CPU power 3518 at time 101.19528140989199
# Task assigned to node with CPU power 2599 at time 102.54636398614852
# Task assigned to node with CPU power 3626 at time 103
# Task assigned to node with CPU power 1539 at time 104.33268356075374
# Task assigned to node with CPU power 2040 at time 106
# Task assigned to node with CPU power 1865 at time 107.29651474530831
# Task assigned to node with CPU power 4206 at time 109
# Task assigned to node with CPU power 4180 at time 110
# Task assigned to node with CPU power 3518 at time 110.67708925525868
# Task assigned to node with CPU power 3042 at time 111
# Task assigned to node with CPU power 4590 at time 112
# Task assigned to node with CPU power 1865 at time 112.18176943699733
# Task assigned to node with CPU power 3353 at time 113
# Task assigned to node with CPU power 3626 at time 116
# Task assigned to node with CPU power 1587 at time 117
# Task assigned to node with CPU power 2792 at time 119
# Task assigned to node with CPU power 3042 at time 120
# Task assigned to node with CPU power 3353 at time 122
# Task assigned to node with CPU power 2599 at time 122.72143131973836
# Task assigned to node with CPU power 3054 at time 123
# Task assigned to node with CPU power 1865 at time 123.47721179624666
# Task assigned to node with CPU power 4180 at time 125
# Task assigned to node with CPU power 4439 at time 126
# Task assigned to node with CPU power 1567 at time 127
# Task assigned to node with CPU power 3626 at time 127.77413127413128
# Task assigned to node with CPU power 3518 at time 128
# Task assigned to node with CPU power 3042 at time 129
# Task assigned to node with CPU power 1587 at time 131
# Task assigned to node with CPU power 1021 at time 132
# Task assigned to node with CPU power 1556 at time 135.37917737789203
# Task assigned to node with CPU power 4206 at time 136
# Task assigned to node with CPU power 1249 at time 136.4443554843875
# Task assigned to node with CPU power 2599 at time 136.97075798383995
# Task assigned to node with CPU power 3518 at time 137
# Task assigned to node with CPU power 2040 at time 138
# Task assigned to node with CPU power 3054 at time 138.09626719056973
# Task assigned to node with CPU power 3626 at time 139.85824600110314
# Task assigned to node with CPU power 1539 at time 142
# Task assigned to node with CPU power 4206 at time 143
# Task assigned to node with CPU power 1556 at time 147.02185089974293
# Task assigned to node with CPU power 1249 at time 147.13290632506005
# Task assigned to node with CPU power 3626 at time 150.80832873690017
# Task assigned to node with CPU power 1556 at time 150.8219794344473
# Task assigned to node with CPU power 3353 at time 152
# Task assigned to node with CPU power 1567 at time 152.58391831525208
# Task assigned to node with CPU power 4439 at time 153
# Task assigned to node with CPU power 3054 at time 154
# Task assigned to node with CPU power 1021 at time 155.55239960822723
# Task assigned to node with CPU power 4590 at time 156
# Task assigned to node with CPU power 2599 at time 156.78914967295114
# Task assigned to node with CPU power 4206 at time 157
# Task assigned to node with CPU power 4439 at time 158.41518359990988
# Task assigned to node with CPU power 2040 at time 158.45098039215685
# Task assigned to node with CPU power 2792 at time 161
# Task assigned to node with CPU power 1587 at time 161.32388153749213
# Task assigned to node with CPU power 1539 at time 162
# Task assigned to node with CPU power 3626 at time 163.95449531163817
# Task assigned to node with CPU power 4439 at time 164
# Task assigned to node with CPU power 2599 at time 165.3105040400154
# Task assigned to node with CPU power 1567 at time 167
# Task assigned to node with CPU power 4206 at time 168
# Task assigned to node with CPU power 2040 at time 168.74313725490194
# Task assigned to node with CPU power 2599 at time 169.30550211619854
# Task assigned to node with CPU power 2792 at time 171
# Task assigned to node with CPU power 1556 at time 171.9595115681234
# Task assigned to node with CPU power 2599 at time 172.06194690265488
# Task assigned to node with CPU power 4590 at time 175
# Task assigned to node with CPU power 2040 at time 175.26617647058822
# Task assigned to node with CPU power 1865 at time 176
# Task assigned to node with CPU power 1021 at time 177.01665034280117
# Task assigned to node with CPU power 4374 at time 178
# Task assigned to node with CPU power 4206 at time 179.62648597242034
# Task assigned to node with CPU power 3054 at time 180
# Task assigned to node with CPU power 3353 at time 181
# Task assigned to node with CPU power 2040 at time 181.22745098039215
# Task assigned to node with CPU power 1567 at time 183.14805360561581
# Task assigned to node with CPU power 2599 at time 183.92920353982302
# Task assigned to node with CPU power 4439 at time 184
# Task assigned to node with CPU power 1249 at time 184.8799039231385
# Task assigned to node with CPU power 1587 at time 185.04473850031508
# Task assigned to node with CPU power 3626 at time 187
# Task assigned to node with CPU power 2599 at time 187.7318199307426
# Task assigned to node with CPU power 2792 at time 187.7919054441261
# Task assigned to node with CPU power 3042 at time 188
# Task assigned to node with CPU power 3518 at time 190
# Task assigned to node with CPU power 1539 at time 190.3170890188434
# Task assigned to node with CPU power 3626 at time 191.47848869277442
# Task assigned to node with CPU power 4206 at time 192.41464574417498
# Task assigned to node with CPU power 2792 at time 193
# Task assigned to node with CPU power 1021 at time 195.02350636630754
# ...
# Task assigned to node with CPU power 3522 at time 195.49488926746162
# Task assigned to node with CPU power 2347 at time 195.75756284618663
# Task assigned to node with CPU power 3587 at time 196.9007527181489
# Task assigned to node with CPU power 4831 at time 197.3307803767336
# Task assigned to node with CPU power 3522 at time 199.26405451448036
# Task assigned to node with CPU power 4831 at time 201.50548540674808
# Task assigned to node with CPU power 4831 at time 204
# Task assigned to node with CPU power 4831 at time 205.26868143241566
# Task assigned to node with CPU power 2322 at time 206.30275624461672
# Task assigned to node with CPU power 2361 at time 207.90343074968234
# Task assigned to node with CPU power 3587 at time 208.73013660440483
# Task assigned to node with CPU power 2347 at time 212.10524073285046
# Task assigned to node with CPU power 2361 at time 212.4015247776366
# Task assigned to node with CPU power 4831 at time 212.619333471331
# Task assigned to node with CPU power 3522 at time 213.18994889267458
# Task assigned to node with CPU power 3587 at time 213.28491775857267
# Task assigned to node with CPU power 3522 at time 214.33077796706414
# Task assigned to node with CPU power 2361 at time 216.90639559508685
# Task assigned to node with CPU power 4831 at time 219.494721589733
# Task assigned to node with CPU power 4831 at time 224.47112399089218
# Task assigned to node with CPU power 3522 at time 711.2654741624077
# Task assigned to node with CPU power 2361 at time 730.208809826345
# Task assigned to node with CPU power 2361 at time 737.7018212621773
# Task assigned to node with CPU power 2361 at time 757.6704786107584
# Task assigned to node with CPU power 2361 at time 771.953833121559
# Task assigned to node with CPU power 2361 at time 781.9927996611609
# Task assigned to node with CPU power 2361 at time 787.664125370606
# Task assigned to node with CPU power 2361 at time 802.6747141041935
# Task assigned to node with CPU power 2361 at time 824.1173231681495
# Task assigned to node with CPU power 2361 at time 846.3244387971203
# Task assigned to node with CPU power 2361 at time 855.3108852181283
# Task assigned to node with CPU power 2724 at time 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 60, in generate_tasks(env, nodes, task_length_range, data_size_range, num_tasks, task_allocation)
#      59 data_size = random.randint(*data_size_range)
# ---> 60 node = nodes[int(task_allocation[task_id])]  # Convert to integer
#      61 task_start_times.append(env.now)
#
# IndexError: list index out of range
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 156
#     153         print(f"Total energy consumption for {num_tasks} tasks: {result['energy_consumption']}")
#     155 if __name__ == "__main__":
# --> 156     main()
#
# Cell In[13], line 130, in main()
#     127 num_iterations = 50
#     129 for num_tasks in TASK_SETS:
# --> 130     gbest_position, gbest_score = qpso_optimize(num_particles, num_iterations, num_tasks, CLOUD_NODES + FOG_NODES)
#     132     env = simpy.Environment()
#     133     cloud_nodes = [
#     134         Node(env, random.randint(*CLOUD_CPU_POWER), CLOUD_RAM, CLOUD_STORAGE, CLOUD_BANDWIDTH)
#     135         for _ in range(CLOUD_NODES)
#     136     ]
#
# Cell In[13], line 105, in qpso_optimize(num_particles, num_iterations, num_tasks, num_nodes)
#      99 fog_nodes = [
#     100     Node(env, random.randint(*FOG_CPU_POWER), FOG_RAM, FOG_STORAGE, FOG_BANDWIDTH)
#     101     for _ in range(FOG_NODES)
#     102 ]
#     103 all_nodes = cloud_nodes + fog_nodes
# --> 105 makespan, energy_consumption = fitness_function(env, all_nodes, num_tasks, particles[i])
#     106 score = makespan + energy_consumption
#     108 if score < pbest_scores[i]:
#
# Cell In[13], line 79, in fitness_function(env, all_nodes, num_tasks, task_allocation)
#      77 def fitness_function(env, all_nodes, num_tasks, task_allocation):
#      78     makespan = env.process(generate_tasks(env, all_nodes, TASK_LENGTH, DATA_SIZE, num_tasks, task_allocation))
# ---> 79     env.run()
#      80     makespan = makespan.value
#      81     total_energy_consumption = sum(node.calculate_energy_consumption(makespan) for node in all_nodes)
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpy\core.py:254, in Environment.run(self, until)
#     252 try:
#     253     while True:
# --> 254         self.step()
#     255 except StopSimulation as exc:
#     256     return exc.args[0]  # == until.value
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpy\core.py:206, in Environment.step(self)
#     204 exc = type(event._value)(*event._value.args)
#     205 exc.__cause__ = event._value
# --> 206 raise exc
#
# IndexError: list index out of range
